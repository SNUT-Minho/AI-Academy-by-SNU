# %%
# import library
import os
import sys
sys.path.append(os.pardir) 
import nltk, re
import numpy as np
import matplotlib.pyplot as plt

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Embedding, Dense, Input, Bidirectional, LSTM, Dropout
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint

import konlpy
from konlpy.tag import Komoran
from konlpy.tag import Twitter
from konlpy.tag import Hannanum
from gensim.models import Word2Vec

import pickle
import codecs
import csv
import struct
# Out:
# Using TensorFlow backend.
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
TEXT_DATA_DIR = './newsData'
directory_label = {0: '정치', 1: '경제', 2: '사회', 3 : '생활/문화', 4 : '세계', 5 : '기술/IT', 6 : '연예', 7 : '스포츠'}

# %%
#WORD_EMBEDDING_WORD2VEC = './wiki.ko/wiki.ko.bin'
#WORD_EMBEDDING_WORD2VEC = './wiki.ko/wiki.ko.vec'

# %%
# parameter
EMBEDDING_DIM = 100
#EMBEDDING_DIM = 200
#EMBEDDING_DIM = 300

# %%
TEST_SPLIT = 0.15
VALIDATION_SPLIT = 0.15

# %%
# konlp Objects
komo = Komoran()
twitter = Twitter()
hannanum = Hannanum()

# %%
# list of texts
Texts = []  
trainTexts = []
validationTexts = []
testTexts = []

# %%
# list of label ids
Labels = []
trainLabels = []  
validationLabels = []
testLabels = []

# %%
# dictionary mapping label name to numeric id
labels_index = {}

# %%
# sequence of texts
seq = []

# %%
print(Texts)
# Out:
# []

# %%
# load texts data
for name in sorted(os.listdir(TEXT_DATA_DIR)):
    path = os.path.join(TEXT_DATA_DIR, name)
    if os.path.isdir(path):
        label_id = len(labels_index)
        labels_index[directory_label[int(name)]] = label_id
        for fname in sorted(os.listdir(path)):
            fpath = os.path.join(path, fname)
            args = {'encoding': 'utf-8'}
            if(re.findall('.1[6789][0-9]NewsData',fpath)):
                # test texts
                text = []
                with open(fpath, **args) as f:
                    t = f.read()
                    #pos = twitter.pos(t.strip())
                    #pos = hannanum.pos(t.strip())
                    pos = komo.pos(t.strip())
                    for pair in pos :
                        #['NNG', 'NNP', 'VV', 'VA']: part-of-speech of content word
                        if (re.findall('^[NV]',pair[1])):
                            morpheme = pair[0]+'/'+pair[1]
                            text.append(morpheme)
                    testTexts.append(text)
                testLabels.append(label_id)
            else :
                # train & validation texts
                text = []
                with open(fpath, **args) as f:
                    t = f.read()
                    #pos = twitter.pos(t.strip())
                    #pos = hannanum.pos(t.strip())
                    pos = komo.pos(t.strip())
                    for pair in pos :
                        if (re.findall('^[NV]',pair[1])):
                            morpheme = pair[0]+'/'+pair[1]
                            text.append(morpheme)
                    Texts.append(text)
                Labels.append(label_id)
            seq.append(text)
print('Found %s texts.' % len(Texts))
print('Found %s texts.' % len(testTexts))
print(len(Labels))
print(len(testLabels))
# Out:
# Found 1280 texts.
# Found 320 texts.
# 1280
# 320

# %%
import seaborn as sns
sns.set(color_codes=True)

'''
print("mean : ", np.mean(trainLen))
print("max : " ,np.max(trainLen))
print("min : " ,np.min(trainLen))
'''
# Out:
# '\nprint("mean : ", np.mean(trainLen))\nprint("max : " ,np.max(trainLen))\nprint("min : " ,np.min(trainLen))\n'

# %%
#MAX_FEATURES = 10000
MAX_FEATURES = 20000
#MAX_FEATURES = 30000

# %%
#Word2Vec
model_ko = Word2Vec(seq, min_count=1, size=EMBEDDING_DIM) 
words = list(model_ko.wv.vocab)
embeddings_index = {}
for i in words:
    embeddings_index[i] = model_ko[i]
# Out:
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
print(len(Texts))
# Out:
# 1280

# %%
# by default, validation_split in `fit` does not shuffle the data
indices = np.arange(len(Texts), dtype=int)
print(type(indices[0]))
# Out:
# <class 'numpy.int32'>

# %%
indices = np.arange(len(Texts))
print(indices)
np.random.shuffle(indices)

Texts = np.array(Texts)
Labels = np.array(Labels)

Texts = Texts[indices]
Labels = Labels[indices]

indices2 = np.arange(len(testTexts))
np.random.shuffle(indices2)

testTexts = np.array(testTexts)
testLabels = np.array(testLabels)

testTexts = testTexts[indices2]
testLabels = testLabels[indices2]
# Out:
# [   0    1    2 ... 1277 1278 1279]

# %%
num_validation_samples = int(VALIDATION_SPLIT * len(Texts))

validationTexts = Texts[:num_validation_samples]
validationLabels = Labels[:num_validation_samples]

trainTexts = Texts[num_validation_samples:]
trainLabels = Labels[num_validation_samples:]

# %%
print(len(trainTexts))
print(len(validationTexts))
print(len(testTexts))
# Out:
# 1088
# 192
# 320

# %%
# train & validation texts의 길이 분포 list
trainLen  = list()
for i in range(len(trainTexts)):
    trainLen.append(len(trainTexts[i]))

# %%
# train & validation texts의 길이 분포 list
validationLen  = list()
for i in range(len(validationTexts)):
    validationLen.append(len(validationTexts[i]))

# %%
# test texts의 길이 분포 list
testLen  = list()
for i in range(len(testTexts)):
    testLen.append(len(testTexts[i]))

# %%
# 각 text별로 길이 분포
sns.distplot(trainLen, hist = True, rug =True);
sns.distplot(validationLen, hist = True, rug =True);
sns.distplot(testLen, hist= True, rug =True)
plt.show()
# Out:
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#MAX_SEQUENCE_LENGTH = 150
#MAX_SEQUENCE_LENGTH = 200
#MAX_SEQUENCE_LENGTH = 250
MAX_SEQUENCE_LENGTH = 300
#MAX_SEQUENCE_LENGTH = 350

# %%
# tokenizer 선언
tokenizer = Tokenizer(num_words=MAX_FEATURES)

TEXT = list()
for i in range(len(trainTexts)):
    TEXT.append(trainTexts[i])
    
for i in range(len(validationTexts)):
    TEXT.append(validationTexts[i]) 
    
for i in range(len(testTexts)):
    TEXT.append(testTexts[i])

# %%
# train on `texts token' (list of sample texts)`
# return list of sequences (one per text)

tokenizer.fit_on_texts(TEXT)
sequences = tokenizer.texts_to_sequences(TEXT)
sequences = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post')
print(len(sequences))
# sequence는 전체?
# Out:
# 1600

# %%
type(trainLabels)
# Out:
# numpy.ndarray

# %%
x_train = sequences[:1088]
y_train = to_categorical(trainLabels)

x_val = sequences[1088:1280]
y_val = to_categorical(validationLabels)

x_test = sequences[1280:]
y_test = to_categorical(testLabels)

# %%
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (1088, 8)
# (192, 8)
# (320, 8)

# %%
print(trainTexts[0])
print(x_train[0])
print(y_train[0])
# Out:
# ['선임/NNG', '기자/NNG', '가/VV', '고흥/NNP', '나로우주센터/NNP', '톤/NNB', '급/NNG', '액체/NNG', '엔진/NNG', '연소/NNG', '시험/NNG', '발사대/NNG', '공정/NNG', '순항/NNG', '월/NNB', '한국형발사체/NNP', '발사/NNG', '앞두/VV', '연구원/NNG', '실험/NNG', '개발/NNG', '구슬땀/NNG', '이달/NNP', '중/NNB', '호/NNB', '이/VCP', '엔진/NNG', '시험/NNG', '돌입/NNG', '서울경제/NNP', '서울/NNP', '서/VV', '전남/NNP', '순천/NNP', '가/VV', '차/NNG', '타/VV', '고흥반도/NNP', '시간/NNG', '걸리/VV', '도착/NNG', '나로우주센터/NNP', '남해안/NNP', '맞붙/VV', '봉래산/NNP', '자락/NNG', '넓/VA', '펼쳐지/VV', '이곳/NP', '오/VV', '월/NNB', '발사/NNG', '단/NNG', '한국형발사체/NNP', '로켓/NNG', '개발/NNG', '실험/NNG', '한창/NNG', '이/VCP', '지나/VV', '년/NNB', '년/NNB', '연속/NNG', '실패/NNG', '끝/NNG', '2013년 1월/NNP', '발사/NNG', '성공/NNG', '나로호/NNP', '때/NNG', '발사체/NNG', '단/NNG', '로켓/NNG', '엔진
'제품/NNG': 249, '종합/NNG': 250, '포함/NNG': 251, '국민/NNG': 252, '원내대표/NNP': 253, '판매/NNG': 254, '보내/VV': 255, '거/NNB': 256, '싶/VX': 257, '찾/VV': 258, '사이/NNG': 259, '내/VX': 260, '협상/NNG': 261, '두/VV': 262, '스마트폰/NNP': 263, '차/NNG': 264, '추가/NNG': 265, '해외/NNG': 266, '회사/NNG': 267, '떨어지/VV': 268, '속/NNG': 269, '남북/NNP': 270, '당국/NNG': 271, '최대/NNG': 272, '민주당/NNP': 273, '남성/NNG': 274, '오늘/NNG': 275, '단체/NNG': 276, '우승/NNG': 277, '덧붙이/VV': 278, '준비/NNG': 279, '개최/NNG': 280, '새롭/VA': 281, '상대/NNG': 282, '운영/NNG': 283, '개 ...

# %%
num_words = min(MAX_FEATURES, len(word_index) + 1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_FEATURES:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all zeros.
        embedding_matrix[i] = embedding_vector

# %%
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix], 
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# %%
# path where all models are saved
BASE_PATH = './newsModel/'
if not os.path.exists(BASE_PATH):
    os.mkdir(BASE_PATH)

# %%
def create_checkpoint(model_name):
    # creates a subdirectory under `BASE_PATH`
    MODEL_PATH = os.path.join(BASE_PATH, model_name)
    if not os.path.exists(MODEL_PATH):
        os.mkdir(MODEL_PATH)
    
    return ModelCheckpoint(filepath=os.path.join(MODEL_PATH, '{epoch:02d}-{val_loss:.4f}.hdf5'),
                           monitor='val_loss',
                           verbose=1,
                           save_best_only=True)

# %%
batch_size = 128
max_epochs = 30
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=3)

# %%
print('Training...')

# train a 3-layer bi-LSTM model
sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)

x = Bidirectional(LSTM(128, return_sequences=True))(embedded_sequences)
x = Dropout(0.5)(x)
x = Bidirectional(LSTM(128, return_sequences=True))(x)
x = Dropout(0.5)(x)
x = Bidirectional(LSTM(128))(x)
x = Dropout(0.5)(x)
preds = Dense(len(labels_index), activation='softmax')(x)

model = Model(sequence_input, preds)

model.compile(loss='categorical_crossentropy',
              optimizer='adagrad',
              metrics=['accuracy'])

checkpoint = create_checkpoint('lstm')  # checkpoint callback
history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=max_epochs,
          validation_data=(x_val, y_val),
          shuffle=True,
          callbacks= [checkpoint])
# Out:
# Training...
# Train on 1088 samples, validate on 192 samples
# Epoch 1/30
# 1088/1088 [==============================] - 720s 662ms/step - loss: 2.2554 - acc: 0.1553 - val_loss: 1.9841 - val_acc: 0.1719
#
# Epoch 00001: val_loss improved from inf to 1.98408, saving model to ./newsModel/lstm\01-1.9841.hdf5
# Epoch 2/30
# 1088/1088 [==============================] - 784s 720ms/step - loss: 1.9798 - acc: 0.2243 - val_loss: 1.8463 - val_acc: 0.2917
#
# Epoch 00002: val_loss improved from 1.98408 to 1.84625, saving model to ./newsModel/lstm\02-1.8463.hdf5
# Epoch 3/30
# 1088/1088 [==============================] - 830s 762ms/step - loss: 1.8827 - acc: 0.2702 - val_loss: 1.7921 - val_acc: 0.3229
#
# Epoch 00003: val_loss improved from 1.84625 to 1.79214, saving model to ./newsModel/lstm\03-1.7921.hdf5
# Epoch 4/30
# 1088/1088 [==============================] - 974s 895ms/step - loss: 1.8562 - acc: 0.3097 - val_loss: 1.6187 - val_acc: 0.4479
#
# Epoch 00004: val_loss improved from 1.79214 to 1.61867, saving model to ./newsModel/lstm\04-1.6187.hdf5
# Epoch 5/30
# 1088/1088 [==============================] - 866s 796ms/step - loss: 1.8001 - acc: 0.3217 - val_loss: 1.6388 - val_acc: 0.4010
#
# Epoch 00005: val_loss did not improve from 1.61867
# Epoch 6/30
# 1088/1088 [==============================] - 770s 708ms/step - loss: 1.6932 - acc: 0.3814 - val_loss: 1.5593 - val_acc: 0.4375
#
# Epoch 00006: val_loss improved from 1.61867 to 1.55929, saving model to ./newsModel/lstm\06-1.5593.hdf5
# Epoch 7/30
# 1088/1088 [==============================] - 733s 674ms/step - loss: 1.7364 - acc: 0.3594 - val_loss: 1.4927 - val_acc: 0.4844
#
# Epoch 00007: val_loss improved from 1.55929 to 1.49275, saving model to ./newsModel/lstm\07-1.4927.hdf5
# Epoch 8/30
# 1088/1088 [==============================] - 712s 654ms/step - loss: 1.6189 - acc: 0.4118 - val_loss: 1.6296 - val_acc: 0.3958
#
# Epoch 00008: val_loss did not improve from 1.49275
# Epoch 9/30
# 1088/1088 [==============================] - 745s 685ms/step - loss: 1.6239 - acc: 0.3980 - val_loss: 1.4484 - val_acc: 0.4740
#
# Epoch 00009: val_loss improved from 1.49275 to 1.44845, saving model to ./newsModel/lstm\09-1.4484.hdf5
# Epoch 10/30
# 1088/1088 [==============================] - 785s 721ms/step - loss: 1.5851 - acc: 0.4081 - val_loss: 1.4183 - val_acc: 0.4792
#
# Epoch 00010: val_loss improved from 1.44845 to 1.41832, saving model to ./newsModel/lstm\10-1.4183.hdf5
# Epoch 11/30
# 1088/1088 [==============================] - 805s 740ms/step - loss: 1.5487 - acc: 0.4430 - val_loss: 1.4341 - val_acc: 0.4635
#
# Epoch 00011: val_loss did not improve from 1.41832
# Epoch 12/30
# 1088/1088 [==============================] - 824s 758ms/step - loss: 1.4670 - acc: 0.4577 - val_loss: 1.3028 - val_acc: 0.5208
#
# Epoch 00012: val_loss improved from 1.41832 to 1.30276, saving model to ./newsModel/lstm\12-1.3028.hdf5
# Epoch 13/30
# 1088/1088 [==============================] - 844s 776ms/step - loss: 1.4455 - acc: 0.4623 - val_loss: 1.3812 - val_acc: 0.4479
#
# Epoch 00013: val_loss did not improve from 1.30276
# Epoch 14/30
# 1088/1088 [==============================] - 858s 789ms/step - loss: 1.4314 - acc: 0.4761 - val_loss: 1.4296 - val_acc: 0.4740
#
# Epoch 00014: val_loss did not improve from 1.30276
# Epoch 15/30
# 1088/1088 [==============================] - 803s 738ms/step - loss: 1.3443 - acc: 0.5000 - val_loss: 1.3661 - val_acc: 0.4896
#
# Epoch 00015: val_loss did not improve from 1.30276
# Epoch 16/30
# 1088/1088 [==============================] - 832s 765ms/step - loss: 1.3577 - acc: 0.5064 - val_loss: 1.4073 - val_acc: 0.5104
#
# Epoch 00016: val_loss did not improve from 1.30276
# Epoch 17/30
# 1088/1088 [==============================] - 919s 844ms/step - loss: 1.3017 - acc: 0.5312 - val_loss: 1.3638 - val_acc: 0.5000
#
# Epoch 00017: val_loss did not improve from 1.30276
# Epoch 18/30
# 1088/1088 [==============================] - 857s 787ms/step - loss: 1.2309 - acc: 0.5561 - val_loss: 1.3663 - val_acc: 0.5104
#
# Epoch 00018: val_loss did not improve from 1.30276
# Epoch 19/30
# 1088/1088 [==============================] - 911s 837ms/step - loss: 1.2212 - acc: 0.5395 - val_loss: 1.2423 - val_acc: 0.5417
#
# Epoch 00019: val_loss improved from 1.30276 to 1.24230, saving model to ./newsModel/lstm\19-1.2423.hdf5
# Epoch 20/30
# 1088/1088 [==============================] - 923s 848ms/step - loss: 1.1635 - acc: 0.5671 - val_loss: 1.3333 - val_acc: 0.5312
#
# Epoch 00020: val_loss did not improve from 1.24230
# Epoch 21/30
# 1088/1088 [==============================] - 731s 672ms/step - loss: 1.1873 - acc: 0.5579 - val_loss: 1.2531 - val_acc: 0.5521
#
# Epoch 00021: val_loss did not improve from 1.24230
# Epoch 22/30
# 1088/1088 [==============================] - 579s 532ms/step - loss: 1.0798 - acc: 0.6158 - val_loss: 1.2799 - val_acc: 0.5208
#
# Epoch 00022: val_loss did not improve from 1.24230
# Epoch 23/30
# 1088/1088 [==============================] - 604s 555ms/step - loss: 1.0498 - acc: 0.6085 - val_loss: 1.2530 - val_acc: 0.5469
#
# Epoch 00023: val_loss did not improve from 1.24230
# Epoch 24/30
# 1088/1088 [==============================] - 621s 570ms/step - loss: 1.1481 - acc: 0.5744 - val_loss: 1.2632 - val_acc: 0.5208
#
# Epoch 00024: val_loss did not improve from 1.24230
# Epoch 25/30
# 1088/1088 [==============================] - 601s 553ms/step - loss: 1.0849 - acc: 0.6131 - val_loss: 1.2047 - val_acc: 0.5521
#
# Epoch 00025: val_loss improved from 1.24230 to 1.20475, saving model to ./newsModel/lstm\25-1.2047.hdf5
# Epoch 26/30
# 1088/1088 [==============================] - 483s 444ms/step - loss: 0.9705 - acc: 0.6599 - val_loss: 1.3328 - val_acc: 0.5521
#
# Epoch 00026: val_loss did not improve from 1.20475
# Epoch 27/30
# 1088/1088 [==============================] - 430s 395ms/step - loss: 0.9466 - acc: 0.6572 - val_loss: 1.3976 - val_acc: 0.4948
#
# Epoch 00027: val_loss did not improve from 1.20475
# Epoch 28/30
# 1088/1088 [==============================] - 458s 421ms/step - loss: 0.9365 - acc: 0.6636 - val_loss: 1.3784 - val_acc: 0.4948
#
# Epoch 00028: val_loss did not improve from 1.20475
# Epoch 29/30
# 1088/1088 [==============================] - 484s 445ms/step - loss: 0.8663 - acc: 0.6682 - val_loss: 1.2645 - val_acc: 0.5521
#
# Epoch 00029: val_loss did not improve from 1.20475
# Epoch 30/30
# 1088/1088 [==============================] - 1148s 1s/step - loss: 0.8696 - acc: 0.6866 - val_loss: 1.1852 - val_acc: 0.5990
#
# Epoch 00030: val_loss improved from 1.20475 to 1.18525, saving model to ./newsModel/lstm\30-1.1852.hdf5

# %%
# Visualize training (optional)
# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots(figsize=(8,8))
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_ylim([0.0, 3.0])

acc_ax.plot(history.history['acc'], 'b', label='train acc')
acc_ax.plot(history.history['val_acc'], 'g', label='val acc')
acc_ax.set_ylim([0.0, 1.0])

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
loss, acc = model.evaluate(x_test, y_test,
                           batch_size=batch_size)

print(f'----- Evaluation loss and metrics for {len(y_test)} test samples -----')
print('Test loss:', loss)
print('Test accuracy:', acc)
# Out:
# 320/320 [==============================] - 10s 30ms/step
# ----- Evaluation loss and metrics for 320 test samples -----
# Test loss: 1.4109184265136718
# Test accuracy: 0.5625
