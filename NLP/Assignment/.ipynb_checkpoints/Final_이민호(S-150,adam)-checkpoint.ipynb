# %%
# import library
import os
import sys
sys.path.append(os.pardir) 
import nltk, re
import numpy as np
import matplotlib.pyplot as plt

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Embedding, Dense, Input, Bidirectional, LSTM, Dropout
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint

import konlpy
from konlpy.tag import Komoran
from konlpy.tag import Twitter
from konlpy.tag import Hannanum
from gensim.models import Word2Vec

import pickle
import codecs
import csv
import struct

# %%
TEXT_DATA_DIR = './newsData'
directory_label = {0: '정치', 1: '경제', 2: '사회', 3 : '생활/문화', 4 : '세계', 5 : '기술/IT', 6 : '연예', 7 : '스포츠'}

# %%
#WORD_EMBEDDING_WORD2VEC = './wiki.ko/wiki.ko.bin'
#WORD_EMBEDDING_WORD2VEC = './wiki.ko/wiki.ko.vec'

# %%
# parameter
EMBEDDING_DIM = 100
#EMBEDDING_DIM = 200
#EMBEDDING_DIM = 300

# %%
TEST_SPLIT = 0.15
VALIDATION_SPLIT = 0.15

# %%
# konlp Objects
komo = Komoran()
twitter = Twitter()
hannanum = Hannanum()

# %%
# list of texts
Texts = []  
trainTexts = []
validationTexts = []
testTexts = []

# %%
# list of label ids
Labels = []
trainLabels = []  
validationLabels = []
testLabels = []

# %%
# dictionary mapping label name to numeric id
labels_index = {}

# %%
# sequence of texts
seq = []

# %%
print(Texts)
# Out:
# []

# %%
# load texts data
for name in sorted(os.listdir(TEXT_DATA_DIR)):
    path = os.path.join(TEXT_DATA_DIR, name)
    if os.path.isdir(path):
        label_id = len(labels_index)
        labels_index[directory_label[int(name)]] = label_id
        for fname in sorted(os.listdir(path)):
            fpath = os.path.join(path, fname)
            args = {'encoding': 'utf-8'}
            if(re.findall('.1[6789][0-9]NewsData',fpath)):
                # test texts
                text = []
                with open(fpath, **args) as f:
                    t = f.read()
                    #pos = twitter.pos(t.strip())
                    #pos = hannanum.pos(t.strip())
                    pos = komo.pos(t.strip())
                    for pair in pos :
                        #['NNG', 'NNP', 'VV', 'VA']: part-of-speech of content word
                        if (re.findall('^[NV]',pair[1])):
                            morpheme = pair[0]+'/'+pair[1]
                            text.append(morpheme)
                    testTexts.append(text)
                testLabels.append(label_id)
            else :
                # train & validation texts
                text = []
                with open(fpath, **args) as f:
                    t = f.read()
                    #pos = twitter.pos(t.strip())
                    #pos = hannanum.pos(t.strip())
                    pos = komo.pos(t.strip())
                    for pair in pos :
                        if (re.findall('^[NV]',pair[1])):
                            morpheme = pair[0]+'/'+pair[1]
                            text.append(morpheme)
                    Texts.append(text)
                Labels.append(label_id)
            seq.append(text)
print('Found %s texts.' % len(Texts))
print('Found %s texts.' % len(testTexts))
print(len(Labels))
print(len(testLabels))
# Out:
# Found 1280 texts.
# Found 320 texts.
# 1280
# 320

# %%
import seaborn as sns
sns.set(color_codes=True)

'''
print("mean : ", np.mean(trainLen))
print("max : " ,np.max(trainLen))
print("min : " ,np.min(trainLen))
'''
# Out:
# '\nprint("mean : ", np.mean(trainLen))\nprint("max : " ,np.max(trainLen))\nprint("min : " ,np.min(trainLen))\n'

# %%
#MAX_FEATURES = 10000
MAX_FEATURES = 20000
#MAX_FEATURES = 30000

# %%
#Word2Vec
model_ko = Word2Vec(seq, min_count=1, size=EMBEDDING_DIM) 
words = list(model_ko.wv.vocab)
embeddings_index = {}
for i in words:
    embeddings_index[i] = model_ko[i]
# Out:
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
print(len(Texts))
# Out:
# 1280

# %%
# by default, validation_split in `fit` does not shuffle the data
indices = np.arange(len(Texts), dtype=int)
print(type(indices[0]))
# Out:
# <class 'numpy.int32'>

# %%
indices = np.arange(len(Texts))
print(indices)
np.random.shuffle(indices)

Texts = np.array(Texts)
Labels = np.array(Labels)

Texts = Texts[indices]
Labels = Labels[indices]

indices2 = np.arange(len(testTexts))
np.random.shuffle(indices2)

testTexts = np.array(testTexts)
testLabels = np.array(testLabels)

testTexts = testTexts[indices2]
testLabels = testLabels[indices2]
# Out:
# [   0    1    2 ... 1277 1278 1279]

# %%
num_validation_samples = int(VALIDATION_SPLIT * len(Texts))

validationTexts = Texts[:num_validation_samples]
validationLabels = Labels[:num_validation_samples]

trainTexts = Texts[num_validation_samples:]
trainLabels = Labels[num_validation_samples:]

# %%
print(len(trainTexts))
print(len(validationTexts))
print(len(testTexts))
# Out:
# 1088
# 192
# 320

# %%
# train & validation texts의 길이 분포 list
trainLen  = list()
for i in range(len(trainTexts)):
    trainLen.append(len(trainTexts[i]))

# %%
# train & validation texts의 길이 분포 list
validationLen  = list()
for i in range(len(validationTexts)):
    validationLen.append(len(validationTexts[i]))

# %%
# test texts의 길이 분포 list
testLen  = list()
for i in range(len(testTexts)):
    testLen.append(len(testTexts[i]))

# %%
# 각 text별로 길이 분포
sns.distplot(trainLen, hist = True, rug =True);
sns.distplot(validationLen, hist = True, rug =True);
sns.distplot(testLen, hist= True, rug =True)
plt.show()
# Out:
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
MAX_SEQUENCE_LENGTH = 150
#MAX_SEQUENCE_LENGTH = 200
#MAX_SEQUENCE_LENGTH = 250
#MAX_SEQUENCE_LENGTH = 300
#MAX_SEQUENCE_LENGTH = 350

# %%
# tokenizer 선언
tokenizer = Tokenizer(num_words=MAX_FEATURES)

TEXT = list()
for i in range(len(trainTexts)):
    TEXT.append(trainTexts[i])
    
for i in range(len(validationTexts)):
    TEXT.append(validationTexts[i]) 
    
for i in range(len(testTexts)):
    TEXT.append(testTexts[i])

# %%
# train on `texts token' (list of sample texts)`
# return list of sequences (one per text)

tokenizer.fit_on_texts(TEXT)
sequences = tokenizer.texts_to_sequences(TEXT)
sequences = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post')
print(len(sequences))
# sequence는 전체?
# Out:
# 1600

# %%
type(trainLabels)
# Out:
# numpy.ndarray

# %%
x_train = sequences[:1088]
y_train = to_categorical(trainLabels)

x_val = sequences[1088:1280]
y_val = to_categorical(validationLabels)

x_test = sequences[1280:]
y_test = to_categorical(testLabels)

# %%
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (1088, 8)
# (192, 8)
# (320, 8)

# %%
print(trainTexts[0])
print(x_train[0])
print(y_train[0])
# Out:
# ['삼성전자/NNP', '년/NNB', '만/NNB', '직원/NNG', '만/NR', '명/NNB', '돌파/NNG', '반도체/NNG', '힘/NNG', '삼성전자/NNP', '직원/NNG', '수/NNB', '년/NNB', '만/NNB', '만/NR', '명/NNB', '넘/VV', '서/VV', '지난해/NNG', '이어지/VV', '글로벌/NNG', '반도체/NNG', '시장/NNG', '수퍼/NNP', '호황/NNG', '힘입/VV', '디바이스/NNP', '솔루션/NNG', '부문/NNG', '채용/NNG', '크/VA', '폭/NNG', '늘/VV', '일/NNB', '삼성전자/NNP', '분기/NNG', '보고서/NNG', '따르/VV', '월/NNB', '말/NNG', '기준/NNG', '본사/NNG', '직원/NNG', '수/NNB', '남성/NNG', '만/NR', '명/NNB', '여성/NNG', '만/NR', '명/NNB', '등/NNB', '만/NR', '명/NNB', '집계/NNG', '지난해/NNG', '말/NNG', '만/NR', '명/NNB', '비하/VV', '늘/VV', '년/NNB', '전/NNG', '이/VCP', '지난해/NNG', '월/NNB', '말/NNG', '만/NR', '명/NNB', '비교/NNG', '증가/NNG', '삼성전자/NNP', '직원/NNG', '수/NNB', '만/NR', '명/NNB', '넘어서/VV', '것/NNB', '삼성디스플레이/NNP', '분사/NNG', '직전/NNG', '해/NNG', '이/VCP', '년/NNB', '이후/NNG', '처음/NNG', '이/VCP', '부문/NNG', '반도체/NNG', '등/NNB', '담당하는\xa0DS부문/NA', '직원/NNG', '수/NNB', '만/NR', '명/NNB', '년/NNB', '전/NNG', '만/NR', '명/NNB', '증가/NNG', '같/VA', '기간/NNG', '소비자/NNG', '가전/NNG', '부문/NNG', '만/NR', '명/NNB', '만/NR', '명/NNB', '소폭/NNG', '줄/VV', '모바일/NNP', '부문/NNG', '만/NR', '명/NNB', '만/NR', '명/NNB', '늘/VV', '기간/NNG', '정하/VV', '없/VA', '근로자/NNG', '정규/NNG', '직/NNG', '만/NR', '명/NNB', '년/NNB', '증가/NNG', '기간/NNG', '근로자/NNG', '명/NNB', '명/NNB', '소폭/NNG', '줄/VV', '직원/NNG', '평균/NNG', '근속/NNG', '연수/NNG', '년/NNB', '년/NNB', '전/NNG', '년/NNB', '늘/VV', '재계/NNG', '관계자/NNG', '반도체/NNG', '업황/NNG', '지속/NNG', '호조/NNG', '보이/VV', '삼성전자/NNP', '최근/NNG', '관련/NNG', '투자/NNG', '일자리/NNG', '늘리/VV', '것/NNB', '보이/VV', '이/VCP', '정규/NNG', '직/NNG', '숫자/NNG', '늘어나/VV', '게/NNG', '의미/NNG', '크/VA', '말/NNG']
# [  218   299    67   233   535   939    90 12466  4322  3418 16158  4551
#   1037   635    39   952   332     5   305   463  1334    29    22    12
#    185  1242   226     8   272    18    17   151    18    17     7    18
#     17  1169    67    12    18    17   629   332     9   109     1    67
#     22    12    18    17   682   182   305   226     8    18    17  3560
#      2  4552 12467  1890  1577     1     9    56   216     1  1037   939
#      7 16159   226     8    18    17     9   109    18    17   182    35
#    319   516  6591  1037    18    17    18    17  2643  1059   494  1037
#     18    17    18    17   332   319  1222    16  1578  4106   831    18
#     17     9   182   319  1578    17    17  2643  1059   226   353  4553
#   4554     9     9   109     9   332  3027    70   939 16160   360  6028
#     31   305    81    47   298  1170   940     2    31     1  4106   831
#   2377   409   120   427    39    12]
# [0. 0. 0. 0. 0. 1. 0. 0.]

# %%
# Map: word -> rank/index(int) in text
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
print(word_index)
# Out:
# Found 25196 unique tokens.
# {'이/VCP': 1, '것/NNB': 2, '있/VV': 3, '하/VV': 4, '일/NNB': 5, '있/VX': 6, '등/NNB': 7, '수/NNB': 8, '년/NNB': 9, '않/VX': 10, '되/VV': 11, '말/NNG': 12, '지/VX': 13, '대하/VV': 14, '원/NNB': 15, '없/VA': 16, '명/NNB': 17, '만/NR': 18, '이/NP': 19, '받/VV': 20, '기자/NNG': 21, '월/NNB': 22, '밝히/VV': 23, '씨/NNB': 24, '위하/VV': 25, '중/NNB': 26, '지나/VV': 27, '보/VV': 28, '따르/VV': 29, '주/VX': 30, '보이/VV': 31, '서울/NNP': 32, '아니/VCN': 33, '억/NR': 34, '같/VA': 35, '북한/NNP': 36, '시간/NNG': 37, '통하/VV': 38, '크/VA': 39, '때/NNG': 40, '대/NNB': 41, '이번/NNG': 42, '미국/NNP': 43, '때문/NNB': 44, '시/NNB': 45, '대통령/NNG': 46, '관련/NNG': 47, '그/NP': 48, '사람/NNG': 49, '이날/NNG': 50, '나오/VV': 51, '경찰/NNG': 52, '김/NNP': 53, '분/NNB': 54, '조사/NNG': 55, '이후/NNG': 56, '한국/NNP': 57, '하/VX': 58, '많/VA': 59, '번/NNB': 60, '중국/NNP': 61, '전하/VV': 62, '개/NNB': 63, '경우/NNG': 64, '대표/NNG': 65, '문제/NNG': 66, '지난해/NNG': 67, '사실/NNG': 68, '후보/NNG': 69, '관계자/NNG': 70, '정부/NNG': 71, '높/VA': 72, '의원/NNG': 73, '못하/VX': 74, '혐의/NNG': 75, '우리/NP': 76, '대회/NNG': 77, '상황/NNG': 78, '점/NNB': 79, '후/NNG': 80, '최근/NNG': 81, '뒤/NNG': 82, '진행/NNG': 83, '측/NNB': 84, '간/NNB': 85, '열리/VV': 86, '오/VV': 87, '좋/VA': 88, '알리/VV': 89, '시장/NNG': 90, '결과/NNG': 91, '위/NNB': 92, '이상/NNG': 93, '수사/NNG': 94, '자신/NNG': 95, '팀/NNG': 96, '지역/NNG': 97, '주장/NNG': 98, '예정/NNG': 99, '확인/NNG': 100, '가/VV': 101, '오/VX': 102, '만/NNB': 103, '들/VV': 104, '오르/VV': 105, '연구/NNG': 106, '시작/NNG': 107, '설명/NNG': 108, '전/NNG': 109, '내/NP': 110, '건/NNB': 111, '사건/NNG': 112, '알/VV': 113, '오후/NNG': 114, '가격/NNG': 115, '조/NR': 116, '만들/VV': 117, '안/NNG': 118, '공개/NNG': 119, '게/NNG': 120, '입장/NNG': 121, '생각/NNG': 122, '국내/NNG': 123, '정도/NNG': 124, '천/NR': 125, '회담/NNG': 126, '당시/NNG': 127, '모습/NNG': 128, '문/NNG': 129, '곳/NNG': 130, '데/NNB': 131, '연합뉴스/NNP': 132, '방송/NNG': 133, '필요/NNG': 134, '미/NNP': 135, '드/NNP': 136, '일/NNG': 137, '회장/NNG': 138, '사용/NNG': 139, '올해/NNG': 140, '세/NNB': 141, '발표/NNG': 142, '트럼프/NNP': 143, '세계/NNG': 144, '위원장/NNG': 145, '일본/NNP': 146, '발생/NNG': 147, '경기/NNG': 148, '이유/NNG': 149, '정상회담/NNP': 150, '여성/NNG': 151, '먹/VV': 152, '사고/NNG': 153, '계획/NNG': 154, '루킹/NNP': 155, '과정/NNG': 156, '일부/NNG': 157, '살/VV': 158, '배/NNG': 159, '검찰/NNG': 160, '앞/NNG': 161, '선수/NNG': 162, '내용/NNG': 163, '상태/NNG': 164, '처리/NNG': 165, '나/NP': 166, '이용/NNG': 167, '국회/NNG': 168, '한국당/NNP': 169, '기록/NNG': 170, '사업/NNG': 171, '오전/NNG': 172, '현지/NNG': 173, '달러/NNB': 174, '수준/NNG': 175, '예상/NNG': 176, '서비스/NNG': 177, '나서/VV': 178, '한편/NNG': 179, '쓰/VV': 180, '논란/NNG': 181, '증가/NNG': 182, '정상/NNG': 183, '차/NNB': 184, '기준/NNG': 185, '내리/VV': 186, '분석/NNG': 187, '달/NNG': 188, '만나/VV': 189, '지적/NNG': 190, '지원/NNG': 191, '규모/NNG': 192, '어렵/VA': 193, '도/NNB': 194, '보도/NNG': 195, '결정/NNG': 196, '북미/NNP': 197, '북/NNP': 198, '합의/NNG': 199, '교수/NNG': 200, '대상/NNG': 201, '지난달/NNG': 202, '집/NNG': 203, '내/VV': 204, '기술/NNG': 205, '요구/NNG': 206, '댓글/NNP': 207, '전망/NNG': 208, '가운데/NNG': 209, '위/NNG': 210, '보/VX': 211, '활동/NNG': 212, '아이/NNG': 213, '만큼/NNB': 214, '출시/NNG': 215, '처음/NNG': 216, '맞/VV': 217, '넘/VV': 218, '사진/NNG': 219, '상승/NNG': 220, '올리/VV': 221, '평가/NNG': 222, '나타나/VV': 223, '특검/NNG': 224, '강조/NNG': 225, '직원/NNG': 226, '관계/NNG': 227, '국제/NNG': 228, '업계/NNG': 229, '그렇/VA': 230, '게임/NNG': 231, '차량/NNG': 232, '이어지/VV': 233, '업체/NNG': 234, '피해/NNG': 235, '개월/NNB': 236, '회/NNB': 237, '최고/NNG': 238, '기업/NNG': 239, '놓/VX': 240, '영향/NNG': 241, '해당/NNG': 242, '열/VV': 243, '발견/NNG': 244, '우려/NNG': 245, '바/NNB': 246, '경제/NNG': 247, '평화/NNG': 248, '제품/NNG': 249, '종합/NNG': 250, '포함/NNG': 251, '국민/NNG': 252, '원내대표/NNP': 253, '판매/NNG': 254, '보내/VV': 255, '거/NNB': 256, '사이/NNG': 257, '찾/VV': 258, '싶/VX': 259, '두/VV': 260, '내/VX': 261, '협상/NNG': 262, '스마트폰/NNP': 263, '추가/NNG': 264, '차/NNG': 265, '해외/NNG': 266, '회사/NNG': 267, '떨어지/VV': 268, '당국/NNG': 269, '속/NNG': 270, '남북/NNP': 271, '남성/NNG': 272, '민주당/NNP': 273, '최대/NNG': 274, '오늘/NNG': 275, '우승/NNG': 276, '단체/NNG': 277, '개최/NNG': 278, '덧붙이/VV': 279, '준비/NNG': 280, '상대/NNG': 281, '새롭/VA': 282, '운영/NNG': 283, '가 ...

# %%
num_words = min(MAX_FEATURES, len(word_index) + 1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_FEATURES:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all zeros.
        embedding_matrix[i] = embedding_vector

# %%
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix], 
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# %%
# path where all models are saved
BASE_PATH = './newsModel/'
if not os.path.exists(BASE_PATH):
    os.mkdir(BASE_PATH)

# %%
def create_checkpoint(model_name):
    # creates a subdirectory under `BASE_PATH`
    MODEL_PATH = os.path.join(BASE_PATH, model_name)
    if not os.path.exists(MODEL_PATH):
        os.mkdir(MODEL_PATH)
    
    return ModelCheckpoint(filepath=os.path.join(MODEL_PATH, '{epoch:02d}-{val_loss:.4f}.hdf5'),
                           monitor='val_loss',
                           verbose=1,
                           save_best_only=True)

# %%
batch_size = 128
max_epochs = 30
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=3)

# %%
print('Training...')

# train a 3-layer bi-LSTM model
sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)

x = Bidirectional(LSTM(128, return_sequences=True))(embedded_sequences)
x = Dropout(0.5)(x)
x = Bidirectional(LSTM(128, return_sequences=True))(x)
x = Dropout(0.5)(x)
x = Bidirectional(LSTM(128))(x)
x = Dropout(0.5)(x)
preds = Dense(len(labels_index), activation='softmax')(x)

model = Model(sequence_input, preds)

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

checkpoint = create_checkpoint('lstm')  # checkpoint callback
history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=max_epochs,
          validation_data=(x_val, y_val),
          shuffle=True,
          callbacks= [checkpoint])
# Out:
# Training...
# Train on 1088 samples, validate on 192 samples
# Epoch 1/30
# 1088/1088 [==============================] - 207s 190ms/step - loss: 2.0387 - acc: 0.1700 - val_loss: 1.8442 - val_acc: 0.2604
#
# Epoch 00001: val_loss improved from inf to 1.84425, saving model to ./newsModel/lstm\01-1.8442.hdf5
# Epoch 2/30
# 1088/1088 [==============================] - 173s 159ms/step - loss: 1.8431 - acc: 0.2877 - val_loss: 1.6955 - val_acc: 0.3281
#
# Epoch 00002: val_loss improved from 1.84425 to 1.69551, saving model to ./newsModel/lstm\02-1.6955.hdf5
# Epoch 3/30
# 1088/1088 [==============================] - 175s 161ms/step - loss: 1.7281 - acc: 0.3539 - val_loss: 1.6223 - val_acc: 0.3958
#
# Epoch 00003: val_loss improved from 1.69551 to 1.62228, saving model to ./newsModel/lstm\03-1.6223.hdf5
# Epoch 4/30
# 1088/1088 [==============================] - 173s 159ms/step - loss: 1.6352 - acc: 0.3888 - val_loss: 1.5612 - val_acc: 0.3958
#
# Epoch 00004: val_loss improved from 1.62228 to 1.56117, saving model to ./newsModel/lstm\04-1.5612.hdf5
# Epoch 5/30
# 1088/1088 [==============================] - 177s 163ms/step - loss: 1.5925 - acc: 0.4035 - val_loss: 1.4835 - val_acc: 0.4531
#
# Epoch 00005: val_loss improved from 1.56117 to 1.48351, saving model to ./newsModel/lstm\05-1.4835.hdf5
# Epoch 6/30
# 1088/1088 [==============================] - 180s 166ms/step - loss: 1.5578 - acc: 0.4283 - val_loss: 1.5386 - val_acc: 0.4271
#
# Epoch 00006: val_loss did not improve from 1.48351
# Epoch 7/30
# 1088/1088 [==============================] - 177s 162ms/step - loss: 1.5079 - acc: 0.4449 - val_loss: 1.4835 - val_acc: 0.4427
#
# Epoch 00007: val_loss did not improve from 1.48351
# Epoch 8/30
# 1088/1088 [==============================] - 188s 173ms/step - loss: 1.4187 - acc: 0.4614 - val_loss: 1.4851 - val_acc: 0.4688
#
# Epoch 00008: val_loss did not improve from 1.48351
# Epoch 9/30
# 1088/1088 [==============================] - 184s 169ms/step - loss: 1.4114 - acc: 0.4871 - val_loss: 1.5687 - val_acc: 0.4167
#
# Epoch 00009: val_loss did not improve from 1.48351
# Epoch 10/30
# 1088/1088 [==============================] - 179s 164ms/step - loss: 1.4009 - acc: 0.4899 - val_loss: 1.4235 - val_acc: 0.4531
#
# Epoch 00010: val_loss improved from 1.48351 to 1.42347, saving model to ./newsModel/lstm\10-1.4235.hdf5
# Epoch 11/30
# 1088/1088 [==============================] - 178s 164ms/step - loss: 1.3938 - acc: 0.4881 - val_loss: 1.4357 - val_acc: 0.4375
#
# Epoch 00011: val_loss did not improve from 1.42347
# Epoch 12/30
# 1088/1088 [==============================] - 181s 167ms/step - loss: 1.3607 - acc: 0.4945 - val_loss: 1.4319 - val_acc: 0.4635
#
# Epoch 00012: val_loss did not improve from 1.42347
# Epoch 13/30
# 1088/1088 [==============================] - 182s 168ms/step - loss: 1.2865 - acc: 0.5303 - val_loss: 1.4588 - val_acc: 0.4688
#
# Epoch 00013: val_loss did not improve from 1.42347
# Epoch 14/30
# 1088/1088 [==============================] - 179s 164ms/step - loss: 1.2797 - acc: 0.5276 - val_loss: 1.4548 - val_acc: 0.4583
#
# Epoch 00014: val_loss did not improve from 1.42347
# Epoch 15/30
# 1088/1088 [==============================] - 179s 164ms/step - loss: 1.2341 - acc: 0.5515 - val_loss: 1.4150 - val_acc: 0.4688
#
# Epoch 00015: val_loss improved from 1.42347 to 1.41499, saving model to ./newsModel/lstm\15-1.4150.hdf5
# Epoch 16/30
# 1088/1088 [==============================] - 180s 166ms/step - loss: 1.2758 - acc: 0.5368 - val_loss: 1.5735 - val_acc: 0.4115
#
# Epoch 00016: val_loss did not improve from 1.41499
# Epoch 17/30
# 1088/1088 [==============================] - 185s 170ms/step - loss: 1.3061 - acc: 0.5147 - val_loss: 1.4853 - val_acc: 0.4375
#
# Epoch 00017: val_loss did not improve from 1.41499
# Epoch 18/30
# 1088/1088 [==============================] - 187s 172ms/step - loss: 1.2410 - acc: 0.5441 - val_loss: 1.4189 - val_acc: 0.4844
#
# Epoch 00018: val_loss did not improve from 1.41499
# Epoch 19/30
# 1088/1088 [==============================] - 183s 168ms/step - loss: 1.2167 - acc: 0.5515 - val_loss: 1.4233 - val_acc: 0.5052
#
# Epoch 00019: val_loss did not improve from 1.41499
# Epoch 20/30
# 1088/1088 [==============================] - 185s 170ms/step - loss: 1.1973 - acc: 0.5524 - val_loss: 1.3490 - val_acc: 0.5000
#
# Epoch 00020: val_loss improved from 1.41499 to 1.34903, saving model to ./newsModel/lstm\20-1.3490.hdf5
# Epoch 21/30
# 1088/1088 [==============================] - 185s 170ms/step - loss: 1.1087 - acc: 0.5956 - val_loss: 1.4230 - val_acc: 0.4896
#
# Epoch 00021: val_loss did not improve from 1.34903
# Epoch 22/30
# 1088/1088 [==============================] - 181s 166ms/step - loss: 1.0678 - acc: 0.6103 - val_loss: 1.5095 - val_acc: 0.4479
#
# Epoch 00022: val_loss did not improve from 1.34903
# Epoch 23/30
# 1088/1088 [==============================] - 185s 170ms/step - loss: 1.0653 - acc: 0.5947 - val_loss: 1.4575 - val_acc: 0.5052
#
# Epoch 00023: val_loss did not improve from 1.34903
# Epoch 24/30
# 1088/1088 [==============================] - 180s 165ms/step - loss: 1.0800 - acc: 0.6204 - val_loss: 1.4538 - val_acc: 0.4740
#
# Epoch 00024: val_loss did not improve from 1.34903
# Epoch 25/30
# 1088/1088 [==============================] - 181s 166ms/step - loss: 1.0243 - acc: 0.6176 - val_loss: 1.4647 - val_acc: 0.4740
#
# Epoch 00025: val_loss did not improve from 1.34903
# Epoch 26/30
# 1088/1088 [==============================] - 182s 167ms/step - loss: 1.0305 - acc: 0.6029 - val_loss: 1.3823 - val_acc: 0.5052
#
# Epoch 00026: val_loss did not improve from 1.34903
# Epoch 27/30
# 1088/1088 [==============================] - 201s 185ms/step - loss: 0.9858 - acc: 0.6369 - val_loss: 1.3963 - val_acc: 0.5260
#
# Epoch 00027: val_loss did not improve from 1.34903
# Epoch 28/30
# 1088/1088 [==============================] - 199s 183ms/step - loss: 0.9034 - acc: 0.6654 - val_loss: 1.3922 - val_acc: 0.5312
#
# Epoch 00028: val_loss did not improve from 1.34903
# Epoch 29/30
# 1088/1088 [==============================] - 189s 174ms/step - loss: 0.8748 - acc: 0.6866 - val_loss: 1.4882 - val_acc: 0.4792
#
# Epoch 00029: val_loss did not improve from 1.34903
# Epoch 30/30
# 1088/1088 [==============================] - 193s 177ms/step - loss: 0.8235 - acc: 0.6967 - val_loss: 1.4796 - val_acc: 0.4740
#
# Epoch 00030: val_loss did not improve from 1.34903

# %%
# Visualize training (optional)
# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots(figsize=(8,8))
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_ylim([0.0, 3.0])

acc_ax.plot(history.history['acc'], 'b', label='train acc')
acc_ax.plot(history.history['val_acc'], 'g', label='val acc')
acc_ax.set_ylim([0.0, 1.0])

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e141f85500c5> in <module>()
#       6 acc_ax = loss_ax.twinx()
#       7
# ----> 8 loss_ax.plot(history.history['loss'], 'y', label='train loss')
#       9 loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
#      10 loss_ax.set_ylim([0.0, 3.0])
#
# NameError: name 'history' is not defined

# %%
loss, acc = model.evaluate(x_test, y_test,
                           batch_size=batch_size)

print(f'----- Evaluation loss and metrics for {len(y_test)} test samples -----')
print('Test loss:', loss)
print('Test accuracy:', acc)
# Out:
# 320/320 [==============================] - 4s 13ms/step
# ----- Evaluation loss and metrics for 320 test samples -----
# Test loss: 1.8770819187164307
# Test accuracy: 0.3
