# %%
# import library
import os
import sys
sys.path.append(os.pardir) 
import nltk, re
import numpy as np
import matplotlib.pyplot as plt

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Embedding, Dense, Input, Bidirectional, LSTM, Dropout
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint

import konlpy
from konlpy.tag import Komoran
from konlpy.tag import Twitter
from konlpy.tag import Hannanum
from gensim.models import Word2Vec

import pickle
import codecs
import csv
import struct
# Out:
# Using TensorFlow backend.
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
TEXT_DATA_DIR = './newsData'
directory_label = {0: '정치', 1: '경제', 2: '사회', 3 : '생활/문화', 4 : '세계', 5 : '기술/IT', 6 : '연예', 7 : '스포츠'}

# %%
#WORD_EMBEDDING_WORD2VEC = './wiki.ko/wiki.ko.bin'
#WORD_EMBEDDING_WORD2VEC = './wiki.ko/wiki.ko.vec'

# %%
# parameter
EMBEDDING_DIM = 100
#EMBEDDING_DIM = 200
#EMBEDDING_DIM = 300

# %%
TEST_SPLIT = 0.15
VALIDATION_SPLIT = 0.15

# %%
# konlp Objects
komo = Komoran()
twitter = Twitter()
hannanum = Hannanum()

# %%
# list of texts
Texts = []  
trainTexts = []
validationTexts = []
testTexts = []

# %%
# list of label ids
Labels = []
trainLabels = []  
validationLabels = []
testLabels = []

# %%
# dictionary mapping label name to numeric id
labels_index = {}

# %%
# sequence of texts
seq = []

# %%
print(Texts)
# Out:
# []

# %%
# load texts data
for name in sorted(os.listdir(TEXT_DATA_DIR)):
    path = os.path.join(TEXT_DATA_DIR, name)
    if os.path.isdir(path):
        label_id = len(labels_index)
        labels_index[directory_label[int(name)]] = label_id
        for fname in sorted(os.listdir(path)):
            fpath = os.path.join(path, fname)
            args = {'encoding': 'utf-8'}
            if(re.findall('.1[6789][0-9]NewsData',fpath)):
                # test texts
                text = []
                with open(fpath, **args) as f:
                    t = f.read()
                    #pos = twitter.pos(t.strip())
                    #pos = hannanum.pos(t.strip())
                    pos = komo.pos(t.strip())
                    for pair in pos :
                        #['NNG', 'NNP', 'VV', 'VA']: part-of-speech of content word
                        if (re.findall('^[NV]',pair[1])):
                            morpheme = pair[0]+'/'+pair[1]
                            text.append(morpheme)
                    testTexts.append(text)
                testLabels.append(label_id)
            else :
                # train & validation texts
                text = []
                with open(fpath, **args) as f:
                    t = f.read()
                    #pos = twitter.pos(t.strip())
                    #pos = hannanum.pos(t.strip())
                    pos = komo.pos(t.strip())
                    for pair in pos :
                        if (re.findall('^[NV]',pair[1])):
                            morpheme = pair[0]+'/'+pair[1]
                            text.append(morpheme)
                    Texts.append(text)
                Labels.append(label_id)
            seq.append(text)
print('Found %s texts.' % len(Texts))
print('Found %s texts.' % len(testTexts))
print(len(Labels))
print(len(testLabels))
# Out:
# Found 1280 texts.
# Found 320 texts.
# 1280
# 320

# %%
import seaborn as sns
sns.set(color_codes=True)

'''
print("mean : ", np.mean(trainLen))
print("max : " ,np.max(trainLen))
print("min : " ,np.min(trainLen))
'''
# Out:
# '\nprint("mean : ", np.mean(trainLen))\nprint("max : " ,np.max(trainLen))\nprint("min : " ,np.min(trainLen))\n'

# %%
#MAX_FEATURES = 10000
MAX_FEATURES = 20000
#MAX_FEATURES = 30000

# %%
#Word2Vec
model_ko = Word2Vec(seq, min_count=1, size=EMBEDDING_DIM) 
words = list(model_ko.wv.vocab)
embeddings_index = {}
for i in words:
    embeddings_index[i] = model_ko[i]
# Out:
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
print(len(Texts))
# Out:
# 1280

# %%
# by default, validation_split in `fit` does not shuffle the data
indices = np.arange(len(Texts), dtype=int)
print(type(indices[0]))
# Out:
# <class 'numpy.int32'>

# %%
indices = np.arange(len(Texts))
print(indices)
np.random.shuffle(indices)

Texts = np.array(Texts)
Labels = np.array(Labels)

Texts = Texts[indices]
Labels = Labels[indices]

indices2 = np.arange(len(testTexts))
np.random.shuffle(indices2)

testTexts = np.array(testTexts)
testLabels = np.array(testLabels)

testTexts = testTexts[indices2]
testLabels = testLabels[indices2]
# Out:
# [   0    1    2 ... 1277 1278 1279]

# %%
num_validation_samples = int(VALIDATION_SPLIT * len(Texts))

validationTexts = Texts[:num_validation_samples]
validationLabels = Labels[:num_validation_samples]

trainTexts = Texts[num_validation_samples:]
trainLabels = Labels[num_validation_samples:]

# %%
print(len(trainTexts))
print(len(validationTexts))
print(len(testTexts))
# Out:
# 1088
# 192
# 320

# %%
# train & validation texts의 길이 분포 list
trainLen  = list()
for i in range(len(trainTexts)):
    trainLen.append(len(trainTexts[i]))

# %%
# train & validation texts의 길이 분포 list
validationLen  = list()
for i in range(len(validationTexts)):
    validationLen.append(len(validationTexts[i]))

# %%
# test texts의 길이 분포 list
testLen  = list()
for i in range(len(testTexts)):
    testLen.append(len(testTexts[i]))

# %%
# 각 text별로 길이 분포
sns.distplot(trainLen, hist = True, rug =True);
sns.distplot(validationLen, hist = True, rug =True);
sns.distplot(testLen, hist= True, rug =True)
plt.show()
# Out:
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#MAX_SEQUENCE_LENGTH = 150
#MAX_SEQUENCE_LENGTH = 200
MAX_SEQUENCE_LENGTH = 250
#MAX_SEQUENCE_LENGTH = 300
#MAX_SEQUENCE_LENGTH = 350

# %%
# tokenizer 선언
tokenizer = Tokenizer(num_words=MAX_FEATURES)

TEXT = list()
for i in range(len(trainTexts)):
    TEXT.append(trainTexts[i])
    
for i in range(len(validationTexts)):
    TEXT.append(validationTexts[i]) 
    
for i in range(len(testTexts)):
    TEXT.append(testTexts[i])

# %%
# train on `texts token' (list of sample texts)`
# return list of sequences (one per text)

tokenizer.fit_on_texts(TEXT)
sequences = tokenizer.texts_to_sequences(TEXT)
sequences = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post')
print(len(sequences))
# sequence는 전체?
# Out:
# 1600

# %%
type(trainLabels)
# Out:
# numpy.ndarray

# %%
x_train = sequences[:1088]
y_train = to_categorical(trainLabels)

x_val = sequences[1088:1280]
y_val = to_categorical(validationLabels)

x_test = sequences[1280:]
y_test = to_categorical(testLabels)

# %%
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (1088, 8)
# (192, 8)
# (320, 8)

# %%
print(trainTexts[0])
print(x_train[0])
print(y_train[0])
# Out:
# ['분기/NNG', '지속/NNG', '사드/NNP', '여파/NNG', '아모레/NNP', '그룹/NNG', '영업/NNG', '익/NNG', '감소/NNG', '아모레퍼시픽그룹/NNP', '분기/NNG', '매출/NNG', '감소/NNG', '에뛰드/NNP', '에스쁘아/NNP', '분기/NNG', '영업/NNG', '적자/NNG', '기록/NNG', '실적/NNG', '개선/NNG', '위하/VV', '글로벌/NNG', '시장/NNG', '공략/NNG', '박차/NNG', '이달/NNG', '헤라/NNP', '싱가포르/NNP', '진출/NNG', '아시아경제/NNP', '박/NNP', '미주/NNG', '기자/NNG', '중국/NNP', '고도/NNG', '미사일방어/NNP', '체계/NNG', '사드/NNP', '배치/NNG', '보복/NNG', '여파/NNG', '올해/NNG', '분기/NNG', '지속/NNG', '아모레퍼시픽그룹/NNP', '분기/NNG', '영업/NNG', '이익/NNG', '감소/NNG', '아모레퍼시픽그룹/NNP', '올해/NNG', '분기/NNG', '전년/NNG', '동기/NNG', '대비/NNG', '감소/NNG', '조/NR', '억/NR', '원/NNB', '매출/NNG', '감소/NNG', '억/NR', '원/NNB', '영업/NNG', '이익/NNG', '기록/NNG', '일/NNB', '밝히/VV', '계열사/NNG', '아모레퍼시픽/NNP', '같/VA', '기간/NNG', '감소/NNG', '조/NR', '억/NR', '원/NNB', '매출/NNG', '감소/NNG', '억/NR', '원/NNB', '영업/NNG', '이익/NNG', '기록/NNG', '주력/NNG', '계열사/NNG', '이/VCP', '아모레퍼시픽/NNP', '중국인/NNG', '관광객/NNG', '감소/NNG', '면세/NNG', '채널/NNG', '유통/NNG', '노력/NNG', '관광/NNG', '상권/NNG', '위축/NNG', '등/NNB', '실적/NNG', '줄/VV', '국내/NNG', '사업/NNG', '매출/NNG', '전년/NNG', '동기/NNG', '대비/NNG', '감소/NNG', '억/NR', '원/NNB', '기록/NNG', '영업/NNG', '이익/NNG', '감소/NNG', '억/NR', '원/NNB', '기록/NNG', '해외/NNG', '사업/NNG', '매출/NNG', '전년/NNG', '동기/NNG', '대비/NNG', '성장/NNG', '억/NR', '원/NNB', '달성/NNG', '영업/NNG', '이익/NNG', '감소/NNG', '억/NR', '원/NNB', '기록/NNG', '아모레퍼시픽/NNP', '아시아/NNP', '사업/NNG', '대/NNB', '글로벌/NNG', '브랜드/NNG', '중심/NNG', '사업/NNG', '확대/NNG', '가속/NNG', '전년/NNG', '동기/NNG', '대비/NNG', '성장/NNG', '억/NR', '원/NNB', '달성/NNG', '설화수/NNP', '자음/NNG', '생수/NNG', '등/NNB', '신제품/NNG', '윤조/NNP', '진설/NNG', '라인/NNG', '등/NNB', '대표/NNG', '제품/NNG', '판매/NNG', '호조/NNG', '이어지/VV', '라네즈/NNP', '퍼펙트/NNP', '리/NNG', '뉴/NNG', '슬/VV', '라인/NNG', '등/NNB', '수분/NNG', '카테고리/NNP', '지속/NNG', '성장/NNG', '레/NNP', '이어링/NNP', '커버/NNG', '쿠션/NNG', '등/NNB', '혁신/NNG', '신제품/NNG', '출시/NNG', '등/NNB', '제품/NNG', '포트폴리오/NNG', '강화/NNG', '마몽드/NNP', '세포/NNG', '이/VCP', '이브/NNP', '앤/NNP', '보이/NNG', '등/NNB', '아세안/NNP', '시장/NNG', '멀티/NNG', '브랜드/NNG', '숍/NNG', '추/VV', '점/NNB', '확대/NNG', '고객/NNG', '접점/NNG', '다변/NNG', '이니스프리/NNP', '화이트/NNP', '피/VV', '톤/NNG', '업/NNG', '크림/NNG', '등/NNB', '중국/NNP', '현지/NNG', '제품/NNG', '출시/NNG', '시장/NNG', '대응력/NNG', '강화/NNG', '일본/NNP', '호/NNB', '점/NNB', '오픈/NNG', '아세안/NNP', '추/VV', '점/NNB', '확대/NNG', '등/NNB', '통하/VV', '글로벌/NNG', '사업/NNG', '가속/NNG', '에뛰드/NNP', '일본/NNP', '시장/NNG', '매출/NNG', '성장/NNG', '지속/NNG', '중국/NNP', '아세안/NNP', 'e커머스/NA', '채널/NNG', '확대/NNG', '등/NNB', '통하/VV', '글로벌/NNG', '메이크업/NNG', '브랜드/NNG', '입지/NNG', '강화/NNG', '북미/NNP', '사업/NNG', '세포/NNG', '라/NNG', '입/NNG', '점/NNG', '라네즈/NNP', '이니스프리/NNP', '플래그/NNP', '십/NR', '스토어/NNP', '판매/NNG', '호조/NNG', '전년/NNG', '동기/NNG', '대비/NNG', '증가/NNG', '억/NR', '원/NNB', '매출/NNG', '기록/NNG', '유럽/NNP', '사업/NNG', '롤리타/NNP', '렘피카/NA', '브랜드/NNG', '라이선스/NNG', '종료/NNG', '영향/NNG', '전년/NNG', '동기/NNG', '대비/NNG', '감소/NNG', '억/NR', '원/NNB', '매출/NNG', '기록/NNG', '새롭/VA', '시장/NNG', '경쟁력/NNG', '확보/NNG', '위하/VV', '아/NNP', '닉/NNP', '딸/NNG', '브랜드/NNG', '리/NNG', '뉴/NNG', '얼/NNG', '추진/NNG', '이니스프리/NNP', '분기/NNG', '매출/NNG', '전년/NNG', '동기/NNG', '감소/NNG', '억/NR', '원/NNB', '영업/NNG', '이익/NNG', '감소/NNG', '억/NR', '원/NNB', '기록/NNG', '관광객/NNG', '감소/NNG', '영향/NNG', '면세/NNG', '채널/NNG', '상권/NNG', '내/NP', '로드/NNP', '숍/NNG', '매출/NNG', '부진/NNG', '같/VA', '기간/NNG', '에뛰드/NNP', '감소/NNG', '억/NR', '원/NNB', '매출/NNG', '기록/NNG', '영업/NNG', '이익/NNG', '적자/NNG', '전환/NNG', '면세/NNG', '채널/NNG', '중심/NNG', '상권/NNG', '매출/NNG', '부진/NNG', '이유/NNG', '이/VCP', '에스쁘아/NNP', '매출/NNG', '억/NR', '원/NNB', '줄/VV', '영업/NNG', '이익/NNG', '적자/NNG', '돌/VV', '서/VV', '에스/NNP', '트/VV', '매출/NNG', '성장/NNG', '억/NR', '원/NNB', '영업/NNG', '이익/NNG', '감소/NNG', '억/NR', '원/NNB', '기록/NNG', '에스/NNP', '트/VV', '이/NP', '너/NP', '뷰티/NNP', '제품/NNG', '판매/NNG', '증가/NNG', '매출/NNG', '소폭/NNG', '증가/NNG', '아모스프로페셔널의/NA', '매출/NNG', '성장/NNG', '억/NR', '원/NNB', '영업/NNG', '이익/NNG', '성장/NNG', '억/NR', '원/NNB', '기록/NNG', '등/NNB', '신제품/NNG', '출시/NNG', '시즌/NNG', '컬러/NNG', '트렌드/NNG', '세미나/NNG', '개최/NNG', '통하/VV', '컬러/NNG', '카테고리/NNP', '경쟁력/NNG', '강화/NNG', '매출/NNG', ...
# [12470   381   146   413    79   647  6031  3418    79   387     7    38
#    535   171  2055 10413   146    90   525   448   360    61  6031 16165
#   1674   387     7    38   535  6592   792  4841   381   196   171  1106
#   1893   682  2645 12468 10419  4107  2807  5177   254  6030  1094  1038
#    358   182    34    15   525   170  1150   171 16166 16167   792  9021
#   1641   241  1094  1038   358   355    34    15   525   170   281    90
#   1306   359    25  2116  6032   574   792  1578  2377  7207   350 10419
#    463   525  1094  1038   355    34    15   750   504   355    34    15
#    170   616   355   241  7205  1674  3923   110  5178  9020   525  1999
#     35   319 10413   355    34    15   525   170   750   504  1997   880
#   7205  1674   562  3923   525  1999   147     1 12466   525    34    15
#   1059   750   504  1997  1675   299  7990   893   525   448    34    15
#    750   504   355    34    15   170  7990   893    19  1482  5572   247
#    254   182   525  2646   182 16168   525   448    34    15   750   504
#    448    34    15   170     7  4322   214  1242  5179  4323 10420   278
#     38  5179 10417  1306   381   525   750   504   448  9019   905  1006
#    284   751   692   905  1547   905     7    41   924  1334  1512   360
#      1   448  6593   460    25  1943   154     1   267    70   782   388
#  12471   460   535   237  2719    25   535    90  3027  3735  1513     1
#    844    26 10414   982  6031    90     1  1037   529    99     1     4
#    360     1   266    90  7208  6033   660   983   154    12]
# [0. 1. 0. 0. 0. 0. 0. 0.]

# %%
# Map: word -> rank/index(int) in text
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
print(word_index)
# Out:
# Found 25196 unique tokens.
# {'이/VCP': 1, '것/NNB': 2, '있/VV': 3, '하/VV': 4, '일/NNB': 5, '있/VX': 6, '등/NNB': 7, '수/NNB': 8, '년/NNB': 9, '않/VX': 10, '되/VV': 11, '말/NNG': 12, '지/VX': 13, '대하/VV': 14, '원/NNB': 15, '없/VA': 16, '명/NNB': 17, '만/NR': 18, '이/NP': 19, '받/VV': 20, '기자/NNG': 21, '월/NNB': 22, '밝히/VV': 23, '씨/NNB': 24, '위하/VV': 25, '중/NNB': 26, '지나/VV': 27, '보/VV': 28, '따르/VV': 29, '주/VX': 30, '보이/VV': 31, '서울/NNP': 32, '아니/VCN': 33, '억/NR': 34, '같/VA': 35, '북한/NNP': 36, '시간/NNG': 37, '통하/VV': 38, '크/VA': 39, '때/NNG': 40, '대/NNB': 41, '이번/NNG': 42, '미국/NNP': 43, '시/NNB': 44, '때문/NNB': 45, '대통령/NNG': 46, '관련/NNG': 47, '그/NP': 48, '사람/NNG': 49, '이날/NNG': 50, '나오/VV': 51, '경찰/NNG': 52, '김/NNP': 53, '분/NNB': 54, '조사/NNG': 55, '이후/NNG': 56, '한국/NNP': 57, '하/VX': 58, '많/VA': 59, '번/NNB': 60, '중국/NNP': 61, '전하/VV': 62, '개/NNB': 63, '경우/NNG': 64, '대표/NNG': 65, '문제/NNG': 66, '지난해/NNG': 67, '사실/NNG': 68, '후보/NNG': 69, '관계자/NNG': 70, '정부/NNG': 71, '높/VA': 72, '못하/VX': 73, '의원/NNG': 74, '혐의/NNG': 75, '우리/NP': 76, '대회/NNG': 77, '상황/NNG': 78, '점/NNB': 79, '후/NNG': 80, '최근/NNG': 81, '뒤/NNG': 82, '진행/NNG': 83, '간/NNB': 84, '측/NNB': 85, '열리/VV': 86, '오/VV': 87, '좋/VA': 88, '알리/VV': 89, '시장/NNG': 90, '결과/NNG': 91, '위/NNB': 92, '이상/NNG': 93, '자신/NNG': 94, '수사/NNG': 95, '팀/NNG': 96, '지역/NNG': 97, '주장/NNG': 98, '예정/NNG': 99, '확인/NNG': 100, '가/VV': 101, '오/VX': 102, '만/NNB': 103, '들/VV': 104, '오르/VV': 105, '연구/NNG': 106, '시작/NNG': 107, '설명/NNG': 108, '전/NNG': 109, '내/NP': 110, '건/NNB': 111, '사건/NNG': 112, '오후/NNG': 113, '알/VV': 114, '가격/NNG': 115, '조/NR': 116, '만들/VV': 117, '안/NNG': 118, '공개/NNG': 119, '게/NNG': 120, '입장/NNG': 121, '생각/NNG': 122, '국내/NNG': 123, '천/NR': 124, '정도/NNG': 125, '회담/NNG': 126, '당시/NNG': 127, '곳/NNG': 128, '모습/NNG': 129, '문/NNG': 130, '데/NNB': 131, '연합뉴스/NNP': 132, '방송/NNG': 133, '필요/NNG': 134, '미/NNP': 135, '드/NNP': 136, '일/NNG': 137, '회장/NNG': 138, '사용/NNG': 139, '올해/NNG': 140, '세/NNB': 141, '세계/NNG': 142, '발표/NNG': 143, '트럼프/NNP': 144, '위원장/NNG': 145, '일본/NNP': 146, '이유/NNG': 147, '발생/NNG': 148, '경기/NNG': 149, '정상회담/NNP': 150, '먹/VV': 151, '여성/NNG': 152, '사고/NNG': 153, '계획/NNG': 154, '루킹/NNP': 155, '과정/NNG': 156, '살/VV': 157, '일부/NNG': 158, '배/NNG': 159, '검찰/NNG': 160, '앞/NNG': 161, '선수/NNG': 162, '내용/NNG': 163, '상태/NNG': 164, '처리/NNG': 165, '나/NP': 166, '이용/NNG': 167, '한국당/NNP': 168, '국회/NNG': 169, '기록/NNG': 170, '사업/NNG': 171, '오전/NNG': 172, '현지/NNG': 173, '달러/NNB': 174, '수준/NNG': 175, '예상/NNG': 176, '서비스/NNG': 177, '나서/VV': 178, '쓰/VV': 179, '한편/NNG': 180, '논란/NNG': 181, '증가/NNG': 182, '정상/NNG': 183, '차/NNB': 184, '기준/NNG': 185, '내리/VV': 186, '만나/VV': 187, '달/NNG': 188, '분석/NNG': 189, '지원/NNG': 190, '지적/NNG': 191, '규모/NNG': 192, '어렵/VA': 193, '도/NNB': 194, '보도/NNG': 195, '북미/NNP': 196, '북/NNP': 197, '결정/NNG': 198, '합의/NNG': 199, '교수/NNG': 200, '대상/NNG': 201, '집/NNG': 202, '지난달/NNG': 203, '내/VV': 204, '기술/NNG': 205, '요구/NNG': 206, '댓글/NNP': 207, '전망/NNG': 208, '가운데/NNG': 209, '보/VX': 210, '위/NNG': 211, '아이/NNG': 212, '활동/NNG': 213, '출시/NNG': 214, '만큼/NNB': 215, '처음/NNG': 216, '맞/VV': 217, '넘/VV': 218, '상승/NNG': 219, '사진/NNG': 220, '평가/NNG': 221, '올리/VV': 222, '나타나/VV': 223, '특검/NNG': 224, '강조/NNG': 225, '국제/NNG': 226, '직원/NNG': 227, '관계/NNG': 228, '차량/NNG': 229, '그렇/VA': 230, '게임/NNG': 231, '업계/NNG': 232, '이어지/VV': 233, '업체/NNG': 234, '개월/NNB': 235, '피해/NNG': 236, '기업/NNG': 237, '회/NNB': 238, '최고/NNG': 239, '놓/VX': 240, '영향/NNG': 241, '해당/NNG': 242, '발견/NNG': 243, '우려/NNG': 244, '열/VV': 245, '바/NNB': 246, '제품/NNG': 247, '경제/NNG': 248, '평화/NNG': 249, '포함/NNG': 250, '종합/NNG': 251, '국민/NNG': 252, '원내대표/NNP': 253, '판매/NNG': 254, '거/NNB': 255, '보내/VV': 256, '찾/VV': 257, '사이/NNG': 258, '싶/VX': 259, '두/VV': 260, '내/VX': 261, '협상/NNG': 262, '스마트폰/NNP': 263, '추가/NNG': 264, '차/NNG': 265, '해외/NNG': 266, '회사/NNG': 267, '떨어지/VV': 268, '속/NNG': 269, '남북/NNP': 270, '당국/NNG': 271, '민주당/NNP': 272, '최대/NNG': 273, '남성/NNG': 274, '오늘/NNG': 275, '단체/NNG': 276, '우승/NNG': 277, '개최/NNG': 278, '덧붙이/VV': 279, '준비/NNG': 280, '새롭/VA': 281, '상대/NNG': 282, '운영/NNG': 283, '개 ...

# %%
num_words = min(MAX_FEATURES, len(word_index) + 1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_FEATURES:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all zeros.
        embedding_matrix[i] = embedding_vector

# %%
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix], 
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# %%
# path where all models are saved
BASE_PATH = './newsModel/'
if not os.path.exists(BASE_PATH):
    os.mkdir(BASE_PATH)

# %%
def create_checkpoint(model_name):
    # creates a subdirectory under `BASE_PATH`
    MODEL_PATH = os.path.join(BASE_PATH, model_name)
    if not os.path.exists(MODEL_PATH):
        os.mkdir(MODEL_PATH)
    
    return ModelCheckpoint(filepath=os.path.join(MODEL_PATH, '{epoch:02d}-{val_loss:.4f}.hdf5'),
                           monitor='val_loss',
                           verbose=1,
                           save_best_only=True)

# %%
batch_size = 128
max_epochs = 300
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=3)

# %%
print('Training...')

# train a 3-layer bi-LSTM model
sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)

x = Bidirectional(LSTM(128, return_sequences=True))(embedded_sequences)
x = Dropout(0.5)(x)
x = Bidirectional(LSTM(128, return_sequences=True))(x)
x = Dropout(0.5)(x)
x = Bidirectional(LSTM(128))(x)
x = Dropout(0.5)(x)
preds = Dense(len(labels_index), activation='softmax')(x)

model = Model(sequence_input, preds)

model.compile(loss='categorical_crossentropy',
              optimizer='adagrad',
              metrics=['accuracy'])

checkpoint = create_checkpoint('lstm')  # checkpoint callback
history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=max_epochs,
          validation_data=(x_val, y_val),
          shuffle=True,
          callbacks= [checkpoint])
# Out:
# Training...

# %%
# Visualize training (optional)
# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots(figsize=(8,8))
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_ylim([0.0, 3.0])

acc_ax.plot(history.history['acc'], 'b', label='train acc')
acc_ax.plot(history.history['val_acc'], 'g', label='val acc')
acc_ax.set_ylim([0.0, 1.0])

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
loss, acc = model.evaluate(x_test, y_test,
                           batch_size=batch_size)

print(f'----- Evaluation loss and metrics for {len(y_test)} test samples -----')
print('Test loss:', loss)
print('Test accuracy:', acc)
# Out:
# 320/320 [==============================] - 7s 21ms/step
# ----- Evaluation loss and metrics for 320 test samples -----
# Test loss: 1.619786262512207
# Test accuracy: 0.471875
