# %%
# import library
import os
import sys
sys.path.append(os.pardir) 
import nltk, re
import numpy as np
import matplotlib.pyplot as plt

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Embedding, Dense, Input, Bidirectional, LSTM, Dropout
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint

import konlpy
from konlpy.tag import Komoran
from konlpy.tag import Twitter
from konlpy.tag import Hannanum
from gensim.models import Word2Vec

import pickle
import codecs
import csv
import struct
# Out:
# Using TensorFlow backend.
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
TEXT_DATA_DIR = './newsData'
directory_label = {0: '정치', 1: '경제', 2: '사회', 3 : '생활/문화', 4 : '세계', 5 : '기술/IT', 6 : '연예', 7 : '스포츠'}

# %%
#WORD_EMBEDDING_WORD2VEC = './wiki.ko/wiki.ko.bin'
#WORD_EMBEDDING_WORD2VEC = './wiki.ko/wiki.ko.vec'

# %%
# parameter
EMBEDDING_DIM = 100
#EMBEDDING_DIM = 200
#EMBEDDING_DIM = 300

# %%
TEST_SPLIT = 0.15
VALIDATION_SPLIT = 0.15

# %%
# konlp Objects
komo = Komoran()
twitter = Twitter()
hannanum = Hannanum()

# %%
# list of texts
Texts = []  
trainTexts = []
validationTexts = []
testTexts = []

# %%
# list of label ids
Labels = []
trainLabels = []  
validationLabels = []
testLabels = []

# %%
# dictionary mapping label name to numeric id
labels_index = {}

# %%
# sequence of texts
seq = []

# %%
print(Texts)
# Out:
# []

# %%
# load texts data
for name in sorted(os.listdir(TEXT_DATA_DIR)):
    path = os.path.join(TEXT_DATA_DIR, name)
    if os.path.isdir(path):
        label_id = len(labels_index)
        labels_index[directory_label[int(name)]] = label_id
        for fname in sorted(os.listdir(path)):
            fpath = os.path.join(path, fname)
            args = {'encoding': 'utf-8'}
            if(re.findall('.1[6789][0-9]NewsData',fpath)):
                # test texts
                text = []
                with open(fpath, **args) as f:
                    t = f.read()
                    #pos = twitter.pos(t.strip())
                    #pos = hannanum.pos(t.strip())
                    pos = komo.pos(t.strip())
                    for pair in pos :
                        #['NNG', 'NNP', 'VV', 'VA']: part-of-speech of content word
                        if (re.findall('^[NV]',pair[1])):
                            morpheme = pair[0]+'/'+pair[1]
                            text.append(morpheme)
                    testTexts.append(text)
                testLabels.append(label_id)
            else :
                # train & validation texts
                text = []
                with open(fpath, **args) as f:
                    t = f.read()
                    #pos = twitter.pos(t.strip())
                    #pos = hannanum.pos(t.strip())
                    pos = komo.pos(t.strip())
                    for pair in pos :
                        if (re.findall('^[NV]',pair[1])):
                            morpheme = pair[0]+'/'+pair[1]
                            text.append(morpheme)
                    Texts.append(text)
                Labels.append(label_id)
            seq.append(text)
print('Found %s texts.' % len(Texts))
print('Found %s texts.' % len(testTexts))
print(len(Labels))
print(len(testLabels))
# Out:
# Found 1280 texts.
# Found 320 texts.
# 1280
# 320

# %%
import seaborn as sns
sns.set(color_codes=True)

'''
print("mean : ", np.mean(trainLen))
print("max : " ,np.max(trainLen))
print("min : " ,np.min(trainLen))
'''
# Out:
# '\nprint("mean : ", np.mean(trainLen))\nprint("max : " ,np.max(trainLen))\nprint("min : " ,np.min(trainLen))\n'

# %%
#MAX_FEATURES = 10000
MAX_FEATURES = 20000
#MAX_FEATURES = 30000

# %%
#Word2Vec
model_ko = Word2Vec(seq, min_count=1, size=EMBEDDING_DIM) 
words = list(model_ko.wv.vocab)
embeddings_index = {}
for i in words:
    embeddings_index[i] = model_ko[i]
# Out:
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
print(len(Texts))
# Out:
# 1280

# %%
# by default, validation_split in `fit` does not shuffle the data
indices = np.arange(len(Texts), dtype=int)
print(type(indices[0]))
# Out:
# <class 'numpy.int32'>

# %%
indices = np.arange(len(Texts))
print(indices)
np.random.shuffle(indices)

Texts = np.array(Texts)
Labels = np.array(Labels)

Texts = Texts[indices]
Labels = Labels[indices]

indices2 = np.arange(len(testTexts))
np.random.shuffle(indices2)

testTexts = np.array(testTexts)
testLabels = np.array(testLabels)

testTexts = testTexts[indices2]
testLabels = testLabels[indices2]
# Out:
# [   0    1    2 ... 1277 1278 1279]

# %%
num_validation_samples = int(VALIDATION_SPLIT * len(Texts))

validationTexts = Texts[:num_validation_samples]
validationLabels = Labels[:num_validation_samples]

trainTexts = Texts[num_validation_samples:]
trainLabels = Labels[num_validation_samples:]

# %%
print(len(trainTexts))
print(len(validationTexts))
print(len(testTexts))
# Out:
# 1088
# 192
# 320

# %%
# train & validation texts의 길이 분포 list
trainLen  = list()
for i in range(len(trainTexts)):
    trainLen.append(len(trainTexts[i]))

# %%
# train & validation texts의 길이 분포 list
validationLen  = list()
for i in range(len(validationTexts)):
    validationLen.append(len(validationTexts[i]))

# %%
# test texts의 길이 분포 list
testLen  = list()
for i in range(len(testTexts)):
    testLen.append(len(testTexts[i]))

# %%
# 각 text별로 길이 분포
sns.distplot(trainLen, hist = True, rug =True);
sns.distplot(validationLen, hist = True, rug =True);
sns.distplot(testLen, hist= True, rug =True)
plt.show()
# Out:
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#MAX_SEQUENCE_LENGTH = 150
#MAX_SEQUENCE_LENGTH = 200
MAX_SEQUENCE_LENGTH = 250
#MAX_SEQUENCE_LENGTH = 300
#MAX_SEQUENCE_LENGTH = 350

# %%
# tokenizer 선언
tokenizer = Tokenizer(num_words=MAX_FEATURES)

TEXT = list()
for i in range(len(trainTexts)):
    TEXT.append(trainTexts[i])
    
for i in range(len(validationTexts)):
    TEXT.append(validationTexts[i]) 
    
for i in range(len(testTexts)):
    TEXT.append(testTexts[i])

# %%
# train on `texts token' (list of sample texts)`
# return list of sequences (one per text)

tokenizer.fit_on_texts(TEXT)
sequences = tokenizer.texts_to_sequences(TEXT)
sequences = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post')
print(len(sequences))
# sequence는 전체?
# Out:
# 1600

# %%
type(trainLabels)
# Out:
# numpy.ndarray

# %%
x_train = sequences[:1088]
y_train = to_categorical(trainLabels)

x_val = sequences[1088:1280]
y_val = to_categorical(validationLabels)

x_test = sequences[1280:]
y_test = to_categorical(testLabels)

# %%
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (1088, 8)
# (192, 8)
# (320, 8)

# %%
print(trainTexts[0])
print(x_train[0])
print(y_train[0])
# Out:
# ['단독/NNG', '신현수/NNP', '조우리/NNP', '공개/NNG', '열애/NNP', '개월/NNB', '결별/NNG', '좋/VA', '동료/NNG', '남/VV', '나/NNG', '영/NNG', '기자/NNG', '배우/NNG', '신현수/NNP', '조우리/NNP', '공개/NNG', '열애/NNP', '개월/NNB', '이/VCP', '연인/NNG', '관계/NNG', '마침표/NNP', '찍/VV', '일/NNB', '취재/NNG', '따르/VV', '신현수/NNP', '조우리/NNP', '최근/NNG', '자연/NNG', '결별/NNG', '수순/NNG', '밟/VV', '이/NP', '지인/NNG', '사람/NNG', '연인/NNG', '자연/NNG', '이별/NNG', '순간/NNG', '좋/VA', '동료/NNG', '남/VV', '하/VV', '귀띔/NNG', '지인/NNG', '어울리/VV', '친분/NNG', '쌓은\xa0두/NA', '사람/NNG', '지나/VV', '하/VV', '월/NNB', '열애/NNP', '초기/NNG', '이/VCP', '인정/NNG', '공식/NNG', '입장/NNG', '밝히/VV', '바다/NNG', '신현수/NNP', '년/NNB', '단편영화/NNP', '백화점/NNG', '으/NNG', '로/NNG', '데뷔/NNG', '후/NNG', '드라마/NNG', '리멤버/NNP', '아들/NNG', '전쟁/NNG', '청춘/NNG', '시대/NNG', '가지/NNB', '색/NNG', '판타지/NNG', '우주/NNG', '별/NNG', '군주/NNG', '가면/NNG', '주인/NNG', '등/NNB', '출연/NNG', '스타/NNG', '연기력/NNG', '겸비/
관계/NNG': 226, '직원/NNG': 227, '국제/NNG': 228, '그렇/VA': 229, '차량/NNG': 230, '게임/NNG': 231, '업계/NNG': 232, '개월/NNB': 233, '업체/NNG': 234, '피해/NNG': 235, '이어지/VV': 236, '최고/NNG': 237, '회/NNB': 238, '기업/NNG': 239, '놓/VX': 240, '영향/NNG': 241, '해당/NNG': 242, '우려/NNG': 243, '열/VV': 244, '발견/NNG': 245, '바/NNB': 246, '제품/NNG': 247, '경제/NNG': 248, '평화/NNG': 249, '종합/NNG': 250, '포함/NNG': 251, '국민/NNG': 252, '원내대표/NNP': 253, '판매/NNG': 254, '보내/VV': 255, '거/NNB': 256, '사이/NNG': 257, '찾/VV': 258, '싶/VX': 259, '두/VV': 260, '협상/NNG': 261, '내/VX': 262, '스마트폰/NNP': 263, '추가/NNG': 264, '차/NNG': 265, '해외/NNG': 266, '회사/NNG': 267, '떨어지/VV': 268, '당국/NNG': 269, '속/NNG': 270, '남북/NNP': 271, '최대/NNG': 272, '남성/NNG': 273, '민주당/NNP': 274, '오늘/NNG': 275, '우승/NNG': 276, '단체/NNG': 277, '준비/NNG': 278, '덧붙이/VV': 279, '개최/NNG': 280, '새롭/VA': 281, '상대/NNG': 282, '운영/NNG': 283, '가 ...

# %%
num_words = min(MAX_FEATURES, len(word_index) + 1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_FEATURES:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all zeros.
        embedding_matrix[i] = embedding_vector

# %%
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix], 
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# %%
# path where all models are saved
BASE_PATH = './newsModel/'
if not os.path.exists(BASE_PATH):
    os.mkdir(BASE_PATH)

# %%
def create_checkpoint(model_name):
    # creates a subdirectory under `BASE_PATH`
    MODEL_PATH = os.path.join(BASE_PATH, model_name)
    if not os.path.exists(MODEL_PATH):
        os.mkdir(MODEL_PATH)
    
    return ModelCheckpoint(filepath=os.path.join(MODEL_PATH, '{epoch:02d}-{val_loss:.4f}.hdf5'),
                           monitor='val_loss',
                           verbose=1,
                           save_best_only=True)

# %%
batch_size = 128
max_epochs = 30
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=3)

# %%
print('Training...')

# train a 3-layer bi-LSTM model
sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)

x = Bidirectional(LSTM(128, return_sequences=True))(embedded_sequences)
x = Dropout(0.5)(x)
x = Bidirectional(LSTM(128, return_sequences=True))(x)
x = Dropout(0.5)(x)
x = Bidirectional(LSTM(128))(x)
x = Dropout(0.5)(x)
preds = Dense(len(labels_index), activation='softmax')(x)

model = Model(sequence_input, preds)

model.compile(loss='categorical_crossentropy',
              optimizer='adagrad',
              metrics=['accuracy'])

checkpoint = create_checkpoint('lstm')  # checkpoint callback
history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=max_epochs,
          validation_data=(x_val, y_val),
          shuffle=True,
          callbacks= [checkpoint])
# Out:
# Training...
# Train on 1088 samples, validate on 192 samples
# Epoch 1/30
# 1088/1088 [==============================] - 290s 267ms/step - loss: 2.2330 - acc: 0.1562 - val_loss: 2.1296 - val_acc: 0.1198
#
# Epoch 00001: val_loss improved from inf to 2.12957, saving model to ./newsModel/lstm\01-2.1296.hdf5
# Epoch 2/30
# 1088/1088 [==============================] - 371s 341ms/step - loss: 2.0631 - acc: 0.1811 - val_loss: 1.9982 - val_acc: 0.2031
#
# Epoch 00002: val_loss improved from 2.12957 to 1.99819, saving model to ./newsModel/lstm\02-1.9982.hdf5
# Epoch 3/30
# 1088/1088 [==============================] - 527s 485ms/step - loss: 1.9959 - acc: 0.2261 - val_loss: 1.9524 - val_acc: 0.2708
#
# Epoch 00003: val_loss improved from 1.99819 to 1.95242, saving model to ./newsModel/lstm\03-1.9524.hdf5
# Epoch 4/30
# 1088/1088 [==============================] - 537s 494ms/step - loss: 1.8841 - acc: 0.2757 - val_loss: 1.7964 - val_acc: 0.3542
#
# Epoch 00004: val_loss improved from 1.95242 to 1.79639, saving model to ./newsModel/lstm\04-1.7964.hdf5
# Epoch 5/30
# 1088/1088 [==============================] - 544s 500ms/step - loss: 1.8735 - acc: 0.2868 - val_loss: 1.7288 - val_acc: 0.3802
#
# Epoch 00005: val_loss improved from 1.79639 to 1.72881, saving model to ./newsModel/lstm\05-1.7288.hdf5
# Epoch 6/30
# 1088/1088 [==============================] - 585s 538ms/step - loss: 1.7669 - acc: 0.3401 - val_loss: 1.7886 - val_acc: 0.3333
#
# Epoch 00006: val_loss did not improve from 1.72881
# Epoch 7/30
# 1088/1088 [==============================] - 682s 627ms/step - loss: 1.6844 - acc: 0.3750 - val_loss: 1.9815 - val_acc: 0.2812
#
# Epoch 00007: val_loss did not improve from 1.72881
# Epoch 8/30
# 1088/1088 [==============================] - 711s 653ms/step - loss: 1.7612 - acc: 0.3373 - val_loss: 1.8299 - val_acc: 0.3438
#
# Epoch 00008: val_loss did not improve from 1.72881
# Epoch 9/30
# 1088/1088 [==============================] - 611s 561ms/step - loss: 1.6753 - acc: 0.3833 - val_loss: 1.6066 - val_acc: 0.3646
#
# Epoch 00009: val_loss improved from 1.72881 to 1.60657, saving model to ./newsModel/lstm\09-1.6066.hdf5
# Epoch 10/30
# 1088/1088 [==============================] - 609s 560ms/step - loss: 1.5519 - acc: 0.4384 - val_loss: 1.7932 - val_acc: 0.3698
#
# Epoch 00010: val_loss did not improve from 1.60657
# Epoch 11/30
# 1088/1088 [==============================] - 600s 551ms/step - loss: 1.6193 - acc: 0.3952 - val_loss: 1.7702 - val_acc: 0.3698
#
# Epoch 00011: val_loss did not improve from 1.60657
# Epoch 12/30
# 1088/1088 [==============================] - 566s 521ms/step - loss: 1.5242 - acc: 0.4485 - val_loss: 1.4618 - val_acc: 0.4167
#
# Epoch 00012: val_loss improved from 1.60657 to 1.46182, saving model to ./newsModel/lstm\12-1.4618.hdf5
# Epoch 13/30
# 1088/1088 [==============================] - 601s 552ms/step - loss: 1.5070 - acc: 0.4403 - val_loss: 1.4724 - val_acc: 0.4427
#
# Epoch 00013: val_loss did not improve from 1.46182
# Epoch 14/30
# 1088/1088 [==============================] - 594s 546ms/step - loss: 1.3974 - acc: 0.4825 - val_loss: 1.3732 - val_acc: 0.4740
#
# Epoch 00014: val_loss improved from 1.46182 to 1.37318, saving model to ./newsModel/lstm\14-1.3732.hdf5
# Epoch 15/30
# 1088/1088 [==============================] - 595s 547ms/step - loss: 1.3892 - acc: 0.5000 - val_loss: 1.4168 - val_acc: 0.4635
#
# Epoch 00015: val_loss did not improve from 1.37318
# Epoch 16/30
# 1088/1088 [==============================] - 610s 560ms/step - loss: 1.2837 - acc: 0.5165 - val_loss: 1.4317 - val_acc: 0.4635
#
# Epoch 00016: val_loss did not improve from 1.37318
# Epoch 17/30
# 1088/1088 [==============================] - 611s 562ms/step - loss: 1.3615 - acc: 0.5175 - val_loss: 1.4377 - val_acc: 0.4427
#
# Epoch 00017: val_loss did not improve from 1.37318
# Epoch 18/30
# 1088/1088 [==============================] - 626s 575ms/step - loss: 1.2268 - acc: 0.5368 - val_loss: 1.3499 - val_acc: 0.4896
#
# Epoch 00018: val_loss improved from 1.37318 to 1.34993, saving model to ./newsModel/lstm\18-1.3499.hdf5
# Epoch 19/30
# 1088/1088 [==============================] - 629s 578ms/step - loss: 1.2684 - acc: 0.5331 - val_loss: 1.3676 - val_acc: 0.5365
#
# Epoch 00019: val_loss did not improve from 1.34993
# Epoch 20/30
# 1088/1088 [==============================] - 625s 575ms/step - loss: 1.2075 - acc: 0.5561 - val_loss: 1.4884 - val_acc: 0.4792
#
# Epoch 00020: val_loss did not improve from 1.34993
# Epoch 21/30
# 1088/1088 [==============================] - 630s 579ms/step - loss: 1.1320 - acc: 0.5928 - val_loss: 1.4513 - val_acc: 0.4635
#
# Epoch 00021: val_loss did not improve from 1.34993
# Epoch 22/30
# 1088/1088 [==============================] - 528s 485ms/step - loss: 1.1867 - acc: 0.5634 - val_loss: 1.3605 - val_acc: 0.5052
#
# Epoch 00022: val_loss did not improve from 1.34993
# Epoch 23/30
# 1088/1088 [==============================] - 544s 500ms/step - loss: 1.0835 - acc: 0.6103 - val_loss: 1.4417 - val_acc: 0.4531
#
# Epoch 00023: val_loss did not improve from 1.34993
# Epoch 24/30
# 1088/1088 [==============================] - 613s 563ms/step - loss: 1.0586 - acc: 0.6075 - val_loss: 1.5000 - val_acc: 0.4062
#
# Epoch 00024: val_loss did not improve from 1.34993
# Epoch 25/30
# 1088/1088 [==============================] - 602s 553ms/step - loss: 1.0560 - acc: 0.6241 - val_loss: 1.3958 - val_acc: 0.4635
#
# Epoch 00025: val_loss did not improve from 1.34993
# Epoch 26/30
# 1088/1088 [==============================] - 581s 534ms/step - loss: 0.9906 - acc: 0.6461 - val_loss: 1.4264 - val_acc: 0.5000
#
# Epoch 00026: val_loss did not improve from 1.34993
# Epoch 27/30
# 1088/1088 [==============================] - 555s 510ms/step - loss: 0.9549 - acc: 0.6664 - val_loss: 1.5216 - val_acc: 0.4635
#
# Epoch 00027: val_loss did not improve from 1.34993
# Epoch 28/30
# 1088/1088 [==============================] - 616s 566ms/step - loss: 0.9219 - acc: 0.6627 - val_loss: 1.4411 - val_acc: 0.4948
#
# Epoch 00028: val_loss did not improve from 1.34993
# Epoch 29/30
# 1088/1088 [==============================] - 592s 544ms/step - loss: 0.8826 - acc: 0.6746 - val_loss: 1.3716 - val_acc: 0.4792
#
# Epoch 00029: val_loss did not improve from 1.34993
# Epoch 30/30
# 1088/1088 [==============================] - 578s 531ms/step - loss: 0.8920 - acc: 0.6857 - val_loss: 1.5346 - val_acc: 0.5000
#
# Epoch 00030: val_loss did not improve from 1.34993

# %%
# Visualize training (optional)
# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots(figsize=(8,8))
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_ylim([0.0, 3.0])

acc_ax.plot(history.history['acc'], 'b', label='train acc')
acc_ax.plot(history.history['val_acc'], 'g', label='val acc')
acc_ax.set_ylim([0.0, 1.0])

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
loss, acc = model.evaluate(x_test, y_test,
                           batch_size=batch_size)

print(f'----- Evaluation loss and metrics for {len(y_test)} test samples -----')
print('Test loss:', loss)
print('Test accuracy:', acc)
# Out:
# 320/320 [==============================] - 7s 21ms/step
# ----- Evaluation loss and metrics for 320 test samples -----
# Test loss: 1.619786262512207
# Test accuracy: 0.471875
