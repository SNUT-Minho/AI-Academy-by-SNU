# %%
# import library
import os
import sys
sys.path.append(os.pardir) 
import nltk, re
import numpy as np
import matplotlib.pyplot as plt

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Embedding, Dense, Input, Bidirectional, LSTM, Dropout
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint

import konlpy
from konlpy.tag import Komoran
from konlpy.tag import Twitter
from konlpy.tag import Hannanum
from gensim.models import Word2Vec

import pickle
import codecs
import csv
import struct
# Out:
# Using TensorFlow backend.
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
TEXT_DATA_DIR = './newsData'
directory_label = {0: '정치', 1: '경제', 2: '사회', 3 : '생활/문화', 4 : '세계', 5 : '기술/IT', 6 : '연예', 7 : '스포츠'}

# %%
#WORD_EMBEDDING_WORD2VEC = './wiki.ko/wiki.ko.bin'
#WORD_EMBEDDING_WORD2VEC = './wiki.ko/wiki.ko.vec'

# %%
# parameter
EMBEDDING_DIM = 100
#EMBEDDING_DIM = 200
#EMBEDDING_DIM = 300

# %%
TEST_SPLIT = 0.15
VALIDATION_SPLIT = 0.15

# %%
# konlp Objects
komo = Komoran()
twitter = Twitter()
hannanum = Hannanum()

# %%
# list of texts
Texts = []  
trainTexts = []
validationTexts = []
testTexts = []

# %%
# list of label ids
Labels = []
trainLabels = []  
validationLabels = []
testLabels = []

# %%
# dictionary mapping label name to numeric id
labels_index = {}

# %%
# sequence of texts
seq = []

# %%
print(Texts)
# Out:
# []

# %%
# load texts data
for name in sorted(os.listdir(TEXT_DATA_DIR)):
    path = os.path.join(TEXT_DATA_DIR, name)
    if os.path.isdir(path):
        label_id = len(labels_index)
        labels_index[directory_label[int(name)]] = label_id
        for fname in sorted(os.listdir(path)):
            fpath = os.path.join(path, fname)
            args = {'encoding': 'utf-8'}
            if(re.findall('.1[6789][0-9]NewsData',fpath)):
                # test texts
                text = []
                with open(fpath, **args) as f:
                    t = f.read()
                    #pos = twitter.pos(t.strip())
                    #pos = hannanum.pos(t.strip())
                    pos = komo.pos(t.strip())
                    for pair in pos :
                        #['NNG', 'NNP', 'VV', 'VA']: part-of-speech of content word
                        if (re.findall('^[NV]',pair[1])):
                            morpheme = pair[0]+'/'+pair[1]
                            text.append(morpheme)
                    testTexts.append(text)
                testLabels.append(label_id)
            else :
                # train & validation texts
                text = []
                with open(fpath, **args) as f:
                    t = f.read()
                    #pos = twitter.pos(t.strip())
                    #pos = hannanum.pos(t.strip())
                    pos = komo.pos(t.strip())
                    for pair in pos :
                        if (re.findall('^[NV]',pair[1])):
                            morpheme = pair[0]+'/'+pair[1]
                            text.append(morpheme)
                    Texts.append(text)
                Labels.append(label_id)
            seq.append(text)
print('Found %s texts.' % len(Texts))
print('Found %s texts.' % len(testTexts))
print(len(Labels))
print(len(testLabels))
# Out:
# Found 1280 texts.
# Found 320 texts.
# 1280
# 320

# %%
import seaborn as sns
sns.set(color_codes=True)

'''
print("mean : ", np.mean(trainLen))
print("max : " ,np.max(trainLen))
print("min : " ,np.min(trainLen))
'''
# Out:
# '\nprint("mean : ", np.mean(trainLen))\nprint("max : " ,np.max(trainLen))\nprint("min : " ,np.min(trainLen))\n'

# %%
#MAX_FEATURES = 10000
MAX_FEATURES = 20000
#MAX_FEATURES = 30000

# %%
#Word2Vec
model_ko = Word2Vec(seq, min_count=1, size=EMBEDDING_DIM) 
words = list(model_ko.wv.vocab)
embeddings_index = {}
for i in words:
    embeddings_index[i] = model_ko[i]
# Out:
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
print(len(Texts))
# Out:
# 1280

# %%
# by default, validation_split in `fit` does not shuffle the data
indices = np.arange(len(Texts), dtype=int)
print(type(indices[0]))
# Out:
# <class 'numpy.int32'>

# %%
indices = np.arange(len(Texts))
print(indices)
np.random.shuffle(indices)

Texts = np.array(Texts)
Labels = np.array(Labels)

Texts = Texts[indices]
Labels = Labels[indices]

indices2 = np.arange(len(testTexts))
np.random.shuffle(indices2)

testTexts = np.array(testTexts)
testLabels = np.array(testLabels)

testTexts = testTexts[indices2]
testLabels = testLabels[indices2]
# Out:
# [   0    1    2 ... 1277 1278 1279]

# %%
num_validation_samples = int(VALIDATION_SPLIT * len(Texts))

validationTexts = Texts[:num_validation_samples]
validationLabels = Labels[:num_validation_samples]

trainTexts = Texts[num_validation_samples:]
trainLabels = Labels[num_validation_samples:]

# %%
print(len(trainTexts))
print(len(validationTexts))
print(len(testTexts))
# Out:
# 1088
# 192
# 320

# %%
# train & validation texts의 길이 분포 list
trainLen  = list()
for i in range(len(trainTexts)):
    trainLen.append(len(trainTexts[i]))

# %%
# train & validation texts의 길이 분포 list
validationLen  = list()
for i in range(len(validationTexts)):
    validationLen.append(len(validationTexts[i]))

# %%
# test texts의 길이 분포 list
testLen  = list()
for i in range(len(testTexts)):
    testLen.append(len(testTexts[i]))

# %%
# 각 text별로 길이 분포
sns.distplot(trainLen, hist = True, rug =True);
sns.distplot(validationLen, hist = True, rug =True);
sns.distplot(testLen, hist= True, rug =True)
plt.show()
# Out:
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#MAX_SEQUENCE_LENGTH = 150
MAX_SEQUENCE_LENGTH = 200
#MAX_SEQUENCE_LENGTH = 250
#MAX_SEQUENCE_LENGTH = 300
#MAX_SEQUENCE_LENGTH = 350

# %%
# tokenizer 선언
tokenizer = Tokenizer(num_words=MAX_FEATURES)

TEXT = list()
for i in range(len(trainTexts)):
    TEXT.append(trainTexts[i])
    
for i in range(len(validationTexts)):
    TEXT.append(validationTexts[i]) 
    
for i in range(len(testTexts)):
    TEXT.append(testTexts[i])

# %%
# train on `texts token' (list of sample texts)`
# return list of sequences (one per text)

tokenizer.fit_on_texts(TEXT)
sequences = tokenizer.texts_to_sequences(TEXT)
sequences = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post')
print(len(sequences))
# sequence는 전체?
# Out:
# 1600

# %%
type(trainLabels)
# Out:
# numpy.ndarray

# %%
x_train = sequences[:1088]
y_train = to_categorical(trainLabels)

x_val = sequences[1088:1280]
y_val = to_categorical(validationLabels)

x_test = sequences[1280:]
y_test = to_categorical(testLabels)

# %%
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (1088, 8)
# (192, 8)
# (320, 8)

# %%
print(trainTexts[0])
print(x_train[0])
print(y_train[0])
# Out:
# ['초소/NNG', '전기차/NNP', '수요/NNG', '폭발/NNG', '조짐/NNG', '국내/NNG', '시장/NNG', '경쟁/NNG', '지/VX', '르노삼성/NNP', '수요/NNG', '늘/VV', '국내/NNG', '예/NNG', '판/NNG', '중/NNB', '파전/NNG', '속/NNG', '업체/NNG', '출시/NNG', '예고/NNG', '디지털타임스/NNP', '김양/NNP', '혁/NNG', '기자/NNG', '초소/NNG', '전기자동차/NNP', '급부상/NNG', '있/VX', '국내/NNG', '시장/NNG', '르노삼성자동차/NNP', '등/NNB', '파전/NNG', '구도/NNG', '형성/NNG', '있/VV', '앞/NNG', '업체/NNG', '초소/NNG', '전기차/NNP', '출시/NNG', '예정/NNG', '이/VCP', '경쟁/NNG', '지/VX', '전망/NNG', '이/VCP', '일/NNB', '우정사업본부/NNP', '따르/VV', '본부/NNG', '전국/NNG', '시험/NNG', '운행/NNG', '중/NNB', '이/VCP', '초소/NNG', '전기차/NNP', '대/NNB', '연내/NNG', '대로/NNB', '늘리/VV', '하/VV', '내년/NNG', '배/NNG', '늘리/VV', '대/NNB', '년/NNB', '대/NNB', '더하/VV', '만/NR', '대/NNB', '가량/NNB', '구매/NNG', '하/VV', '기존/NNG', '우편/NNG', '배달/NNG', '사용/NNG', '이륜차/NNP', '초소/NNG', '전기차/NNP', '교체/NNG', '계획/NNG', '이/VCP', '이/NP', '따르/VV', '작년/NNG', '판매량/NNG', '대/NNB', '국내/NNG', '초소/NNG', '전기차/NNP', '시장/NNG', '앞/NNG', '년/NNB', '내/NP', '최소/NNG', '배/NNG', '이상/NNG', '커지/VV', '전망/NNG', '이/VCP', '여기/NP', '민간/NNG', '초소/NNG', '전기차/NNP', '수요/NNG', '더하/VV', '지/VX', '성장세/NNG', '가/VV', '팔/VV', '지/VX', '것/NNB', '보이/VV', '우정사업본부/NNP', '시험/NNG', '사업/NNG', '참가/NNG', '업체/NNG', '르노삼성자동차/NNP', '쎄미시스코,/NA', '대창/NNP', '모터스/NNP', '등/NNB', '개/NNB', '업체/NNG', '르노삼성/NNP', '수입/NNG', '판매/NNG', '중/NNB', '이/VCP', '초소/NNG', '전기차/NNP', "'트위지'/NA", '수요/NNG', '늘어나/VV', '국내/NNG', '생산/NNG', '검토/NNG', '계획/NNG', '이/VCP', '회사/NNG', '들/VV', '월/NNB', '대/NNB', '판매/NNG', '작년/NNG', '판매량/NNG', '대/NNB', '육박/NNG', '프랑스/NNP', '르노/NNP', '본사/NNG', '트위지/NA', '연간/NNG', '생산량/NNG', '대/NNB', '이/VCP', '가운데/NNG', '르노삼성/NNP', '배정/NNG', '물량/NNG', '대/NNB', '달하/VV', '대창/NNP', '모터스/NNP', '올해/NNG', '월/NNB', '전자상거래/NNP', '업체/NNG', '티켓몬스터/NNP', '초소/NNG', '전기차/NNP', '다니/VV', '대/NNB', '예약/NNG', '판매/NNG', '실시/NNG', '반나절/NNG', '만/NNB', '판매/NNG', '추가/NNG', '대/NNB', '예약/NNG', '판매/NNG', '물량/NNG', '순식간/NNG', '팔리/VV', '나가/VX', '쎄미시스코는/NA', '월/NNB', '전국/NNG', '이마트/NNP', '매장/NNG', '초소/NNG', '전기차/NNP', '예약/NNG', '판매/NNG', '하/VV', '있/VX', 'D2/NNP', '중국/NNP', '즈더우가/NA', '생산/NNG', '차량/NNG', '쎄미시스코가/NA', '수입/NNG', '판매/NNG', '있/VX', '올해/NNG', '7월 1일/NNP', '소형/NNG', '전기차/NNP', '출시/NNG', '국내/NNG', '세종시/NNP', '공장/NNG', '생산/NNG', '계획/NNG', '공장/NNG', '연간/NNG', '생산/NNG', '능력/NNG', '대/NNB', '국내/NNG', '전기차/NNP', '판매량/NNG', '급증/NNG', '있/VX', '국토교통부/NNP', '따르/VV', '올해/NNG', '월/NNB', '기준/NNG', '국내/NNG', '등록/NNG', '누적/NNG', '전기차/NNP', '만/NR', '대/NNB', '작년/NNG', '월/NNB', '만/NR', '대/NNB', '비하/VV', '대/NNB', '늘/VV', '이/NP', '따르/VV', '올해/NNG', '국내/NNG', '전기차/NNP', '판매량/NNG', '작년/NNG', '배/NNG', '이상/NNG', '늘어나/VV', '만/NR', '대/NNB', '넘/VV', '것/NNB', '예상/NNG']
# [  159   939    41     9    41  1106    18    41   742   844     4   435
#   7990  4551   139 16159  2552  1378   925   154     1    19    29   478
#   1482    41   123  2552  1378    90   161     9   110   952   159    93
#    381   208     1   697  2116  2552  1378   716  1106    13  3734   101
#    845    13     2    31 12468  1140   171   585   233 12467 16160 12469
#  12470     7    63   233 10413   751   254    26     1  2552  1378 16161
#    716   409   123   413   448   154     1   267   104    22    41   254
#    478  1482    41  4552   926 16162  1242 16163  1202  3028    41     1
#    209 10413  2907  1334    41   621 12469 12470   140    22 12471   233
#  16164  2552  1378  1059    41   635   254   682 10414   103   254   264
#     41   635   254  1334  5176  2377   982 16165    22   292  7991   734
#   2552  1378   635   254     4     6 16166    61 16167   413   229 16168
#    751   254     6   140 12472  3029  1378   214   123 10415  1060   413
#    154  1060  1202   413   953    41   123  1378  1482  2553     6  2643
#     29   140    22   185   123   644  2908  1378    18    41   478    22
#     18    41   629    41   332    19    29   140   123  1378  1482   478
#    159    93   409    18    41   218     2   176]
# [0. 0. 0. 1. 0. 0. 0. 0.]

# %%
# Map: word -> rank/index(int) in text
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
print(word_index)
# Out:
# Found 25196 unique tokens.
# {'이/VCP': 1, '것/NNB': 2, '있/VV': 3, '하/VV': 4, '일/NNB': 5, '있/VX': 6, '등/NNB': 7, '수/NNB': 8, '년/NNB': 9, '않/VX': 10, '되/VV': 11, '말/NNG': 12, '지/VX': 13, '대하/VV': 14, '원/NNB': 15, '없/VA': 16, '명/NNB': 17, '만/NR': 18, '이/NP': 19, '받/VV': 20, '기자/NNG': 21, '월/NNB': 22, '밝히/VV': 23, '씨/NNB': 24, '위하/VV': 25, '중/NNB': 26, '지나/VV': 27, '보/VV': 28, '따르/VV': 29, '주/VX': 30, '보이/VV': 31, '서울/NNP': 32, '아니/VCN': 33, '억/NR': 34, '같/VA': 35, '북한/NNP': 36, '시간/NNG': 37, '통하/VV': 38, '크/VA': 39, '때/NNG': 40, '대/NNB': 41, '이번/NNG': 42, '미국/NNP': 43, '시/NNB': 44, '때문/NNB': 45, '대통령/NNG': 46, '관련/NNG': 47, '그/NP': 48, '사람/NNG': 49, '이날/NNG': 50, '나오/VV': 51, '경찰/NNG': 52, '김/NNP': 53, '분/NNB': 54, '조사/NNG': 55, '이후/NNG': 56, '한국/NNP': 57, '하/VX': 58, '많/VA': 59, '번/NNB': 60, '중국/NNP': 61, '전하/VV': 62, '개/NNB': 63, '경우/NNG': 64, '대표/NNG': 65, '문제/NNG': 66, '지난해/NNG': 67, '사실/NNG': 68, '후보/NNG': 69, '관계자/NNG': 70, '정부/NNG': 71, '못하/VX': 72, '높/VA': 73, '의원/NNG': 74, '혐의/NNG': 75, '우리/NP': 76, '대회/NNG': 77, '상황/NNG': 78, '점/NNB': 79, '후/NNG': 80, '뒤/NNG': 81, '최근/NNG': 82, '진행/NNG': 83, '측/NNB': 84, '간/NNB': 85, '열리/VV': 86, '오/VV': 87, '좋/VA': 88, '알리/VV': 89, '시장/NNG': 90, '결과/NNG': 91, '위/NNB': 92, '이상/NNG': 93, '수사/NNG': 94, '자신/NNG': 95, '지역/NNG': 96, '팀/NNG': 97, '주장/NNG': 98, '예정/NNG': 99, '확인/NNG': 100, '가/VV': 101, '오/VX': 102, '만/NNB': 103, '들/VV': 104, '오르/VV': 105, '연구/NNG': 106, '시작/NNG': 107, '설명/NNG': 108, '전/NNG': 109, '내/NP': 110, '건/NNB': 111, '사건/NNG': 112, '알/VV': 113, '오후/NNG': 114, '가격/NNG': 115, '조/NR': 116, '안/NNG': 117, '만들/VV': 118, '공개/NNG': 119, '게/NNG': 120, '입장/NNG': 121, '생각/NNG': 122, '국내/NNG': 123, '천/NR': 124, '정도/NNG': 125, '회담/NNG': 126, '당시/NNG': 127, '모습/NNG': 128, '곳/NNG': 129, '문/NNG': 130, '데/NNB': 131, '연합뉴스/NNP': 132, '방송/NNG': 133, '필요/NNG': 134, '미/NNP': 135, '드/NNP': 136, '일/NNG': 137, '회장/NNG': 138, '사용/NNG': 139, '올해/NNG': 140, '세/NNB': 141, '발표/NNG': 142, '세계/NNG': 143, '트럼프/NNP': 144, '위원장/NNG': 145, '일본/NNP': 146, '발생/NNG': 147, '경기/NNG': 148, '이유/NNG': 149, '정상회담/NNP': 150, '먹/VV': 151, '여성/NNG': 152, '사고/NNG': 153, '계획/NNG': 154, '루킹/NNP': 155, '과정/NNG': 156, '일부/NNG': 157, '살/VV': 158, '배/NNG': 159, '검찰/NNG': 160, '앞/NNG': 161, '선수/NNG': 162, '내용/NNG': 163, '상태/NNG': 164, '처리/NNG': 165, '나/NP': 166, '이용/NNG': 167, '한국당/NNP': 168, '국회/NNG': 169, '기록/NNG': 170, '사업/NNG': 171, '오전/NNG': 172, '현지/NNG': 173, '달러/NNB': 174, '수준/NNG': 175, '예상/NNG': 176, '서비스/NNG': 177, '나서/VV': 178, '한편/NNG': 179, '쓰/VV': 180, '논란/NNG': 181, '정상/NNG': 182, '증가/NNG': 183, '차/NNB': 184, '기준/NNG': 185, '내리/VV': 186, '달/NNG': 187, '분석/NNG': 188, '만나/VV': 189, '지원/NNG': 190, '지적/NNG': 191, '규모/NNG': 192, '어렵/VA': 193, '도/NNB': 194, '보도/NNG': 195, '결정/NNG': 196, '북미/NNP': 197, '합의/NNG': 198, '북/NNP': 199, '교수/NNG': 200, '대상/NNG': 201, '지난달/NNG': 202, '집/NNG': 203, '내/VV': 204, '기술/NNG': 205, '요구/NNG': 206, '댓글/NNP': 207, '전망/NNG': 208, '가운데/NNG': 209, '위/NNG': 210, '보/VX': 211, '아이/NNG': 212, '활동/NNG': 213, '출시/NNG': 214, '만큼/NNB': 215, '처음/NNG': 216, '맞/VV': 217, '넘/VV': 218, '상승/NNG': 219, '사진/NNG': 220, '나타나/VV': 221, '올리/VV': 222, '평가/NNG': 223, '특검/NNG': 224, '강조/NNG': 225, '직원/NNG': 226, '관계/NNG': 227, '국제/NNG': 228, '차량/NNG': 229, '그렇/VA': 230, '게임/NNG': 231, '업계/NNG': 232, '업체/NNG': 233, '이어지/VV': 234, '피해/NNG': 235, '개월/NNB': 236, '회/NNB': 237, '기업/NNG': 238, '최고/NNG': 239, '놓/VX': 240, '해당/NNG': 241, '영향/NNG': 242, '열/VV': 243, '발견/NNG': 244, '우려/NNG': 245, '바/NNB': 246, '경제/NNG': 247, '제품/NNG': 248, '평화/NNG': 249, '종합/NNG': 250, '포함/NNG': 251, '국민/NNG': 252, '원내대표/NNP': 253, '판매/NNG': 254, '거/NNB': 255, '보내/VV': 256, '찾/VV': 257, '싶/VX': 258, '사이/NNG': 259, '두/VV': 260, '내/VX': 261, '협상/NNG': 262, '스마트폰/NNP': 263, '추가/NNG': 264, '차/NNG': 265, '해외/NNG': 266, '회사/NNG': 267, '떨어지/VV': 268, '속/NNG': 269, '당국/NNG': 270, '남북/NNP': 271, '민주당/NNP': 272, '최대/NNG': 273, '남성/NNG': 274, '오늘/NNG': 275, '단체/NNG': 276, '우승/NNG': 277, '준비/NNG': 278, '개최/NNG': 279, '덧붙이/VV': 280, '상대/NNG': 281, '운영/NNG': 282, '새롭/VA': 283, '가 ...

# %%
num_words = min(MAX_FEATURES, len(word_index) + 1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_FEATURES:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all zeros.
        embedding_matrix[i] = embedding_vector

# %%
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix], 
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# %%
# path where all models are saved
BASE_PATH = './newsModel/'
if not os.path.exists(BASE_PATH):
    os.mkdir(BASE_PATH)

# %%
def create_checkpoint(model_name):
    # creates a subdirectory under `BASE_PATH`
    MODEL_PATH = os.path.join(BASE_PATH, model_name)
    if not os.path.exists(MODEL_PATH):
        os.mkdir(MODEL_PATH)
    
    return ModelCheckpoint(filepath=os.path.join(MODEL_PATH, '{epoch:02d}-{val_loss:.4f}.hdf5'),
                           monitor='val_loss',
                           verbose=1,
                           save_best_only=True)

# %%
batch_size = 128
max_epochs = 30
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=3)

# %%
print('Training...')

# train a 3-layer bi-LSTM model
sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)

x = Bidirectional(LSTM(128, return_sequences=True))(embedded_sequences)
x = Dropout(0.5)(x)
x = Bidirectional(LSTM(128, return_sequences=True))(x)
x = Dropout(0.5)(x)
x = Bidirectional(LSTM(128))(x)
x = Dropout(0.5)(x)
preds = Dense(len(labels_index), activation='softmax')(x)

model = Model(sequence_input, preds)

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

checkpoint = create_checkpoint('lstm')  # checkpoint callback
history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=max_epochs,
          validation_data=(x_val, y_val),
          shuffle=True,
          callbacks= [checkpoint])
# Out:
# Training...
# Train on 1088 samples, validate on 192 samples
# Epoch 1/200
# 1088/1088 [==============================] - 297s 273ms/step - loss: 2.0326 - acc: 0.1765 - val_loss: 1.8921 - val_acc: 0.3177
#
# Epoch 00001: val_loss improved from inf to 1.89213, saving model to ./newsModel/lstm\01-1.8921.hdf5
# Epoch 2/200
# 1024/1088 [===========================>..] - ETA: 15s - loss: 1.8781 - acc: 0.2793

# %%
# Visualize training (optional)
# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots(figsize=(8,8))
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_ylim([0.0, 3.0])

acc_ax.plot(history.history['acc'], 'b', label='train acc')
acc_ax.plot(history.history['val_acc'], 'g', label='val acc')
acc_ax.set_ylim([0.0, 1.0])

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
loss, acc = model.evaluate(x_test, y_test,
                           batch_size=batch_size)

print(f'----- Evaluation loss and metrics for {len(y_test)} test samples -----')
print('Test loss:', loss)
print('Test accuracy:', acc)
# Out:
# 320/320 [==============================] - 4s 13ms/step
# ----- Evaluation loss and metrics for 320 test samples -----
# Test loss: 1.8770819187164307
# Test accuracy: 0.3
