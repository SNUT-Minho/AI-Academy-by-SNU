# %%
import os
import sys
sys.path.append(os.pardir) 
import nltk, re
import numpy as np
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Embedding, Dense, Input, Bidirectional, LSTM
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint

import konlpy
from konlpy.tag import Komoran
from konlpy.tag import Twitter
from konlpy.tag import Hannanum
from gensim.models import Word2Vec

# %%
TEXT_DATA_DIR = './newsData'
MAX_SEQUENCE_LENGTH = 1000
MAX_FEATURES = 20000
EMBEDDING_DIM = 100
TEST_SPLIT = 0.15

# %%
trainTexts = []  # list of text samples
testTexts = [] 
labels_index = {}  # dictionary mapping label name to numeric id
trainLabels = []  # list of label ids
testLabels = []
seq = []
komo = Komoran()

for name in sorted(os.listdir(TEXT_DATA_DIR)):
    path = os.path.join(TEXT_DATA_DIR, name)
    if os.path.isdir(path):
        label_id = len(labels_index)
        labels_index[name] = label_id
        for fname in sorted(os.listdir(path)):
            fpath = os.path.join(path, fname)
  
            args = {'encoding': 'utf-8'}
            if(re.findall('.1[6789][0-9]NewsData',fpath)):
                text = []
                with open(fpath, **args) as f:
                    t = f.read()
                    pos = komo.pos(t.strip())
                    for pair in pos :
                        if (re.findall('^[NV]',pair[1])):
                            morpheme = pair[0]+'/'+pair[1]
                            text.append(morpheme)
                    testTexts.append(text)
                testLabels.append(label_id)
            else :
                text = []
                with open(fpath, **args) as f:
                    t = f.read()
                    pos = komo.pos(t.strip())
                    for pair in pos :
                        if (re.findall('^[NV]',pair[1])):
                            morpheme = pair[0]+'/'+pair[1]
                            text.append(morpheme)
                    trainTexts.append(text)
                trainLabels.append(label_id)
            seq.append(text)
print('Found %s texts.' % len(trainTexts))
print('Found %s texts.' % len(testTexts))
print(len(trainLabels))
print(len(testLabels))
# Out:
# Found 1280 texts.
# Found 320 texts.
# 1280
# 320

# %%
li  = list()
for i in range(len(trainTexts)):
    print(len(trainTexts[i]))
# Out:
# 180
# 125
# 512
# 333
# 505
# 201
# 685
# 278
# 261
# 330
# 484
# 327
# 215
# 384
# 293
# 419
# 235
# 383
# 203
# 303
# 367
# 295
# 236
# 327
# 205
# 291
# 378
# 200
# 265
# 336
# 232
# 411
# 562
# 251
# 169
# 200
# 375
# 308
# 293
# 445
# 445
# 390
# 454
# 243
# 303
# 209
# 187
# 363
# 122
# 288
# 293
# 434
# 195
# 257
# 289
# 399
# 190
# 195
# 607
# 340
# 292
# 292
# 223
# 303
# 193
# 172
# 323
# 267
# 217
# 392
# 374
# 371
# 160
# 226
# 323
# 443
# 176
# 394
# 201
# 170
# 301
# 248
# 160
# 205
# 282
# 434
# 493
# 529
# 317
# 171
# 610
# 184
# 436
# 253
# 295
# 269
# 176
# 225
# 428
# 434
# 129
# 163
# 318
# 229
# 282
# 321
# 205
# 502
# 245
# 129
# 179
# 166
# 126
# 243
# 514
# 229
# 214
# 282
# 206
# 277
# 321
# 423
# 312
# 445
# 258
# 367
# 201
# 178
# 430
# 278
# 265
# 260
# 417
# 285
# 370
# 569
# 206
# 378
# 195
# 321
# 133
# 206
# 251
# 235
# 321
# 211
# 302
# 256
# 195
# 444
# 367
# 212
# 129
# 334
# 148
# 183
# 296
# 416
# 223
# 537
# 474
# 271
# 247
# 288
# 221
# 532
# 250
# 361
# 237
# 351
# 117
# 190
NNG', '하/VV', '이/VCP', '개/NNB', '교섭단체/NNP', '예결/NNG', '위/NNG', '간사/NNG', '참석/NNG', '소위/NNG', '심사/NNG', '지/NNB', '시간/NNG', '만/NNB', '여야/NNG', '간/NNB', '충돌/NNG', '정회/NNG', '자유/NNG', '한국당/NNP', '예결/NNG', '위/NNG', '간사/NNG', '이/VCP', '김도읍/NNP', '의원/NNG', '감액/NNG', '사업/NNG', '많/VA', '소위/NNG', '정회/NNG', '상태/NNG', '말/NNG', '예결/NNG', '위/NNG', '소위/NNG', '감액/NNG', '심사/NNG', '완료/NNG', '증액/NNG', '작업/NNG', '등/NNB', '거치/VV', '수정/NNG', '추경안/NNG', '전체/NNG', '회의/NNG', '올리/VV', '예정/NNG', '이/VCP', '현재/NNG', '전체/NNG', '회의/NNG', '개/NNB', '상정/NNG', '전망/NNG', '불투명/NNG', '상태/NNG', '이/VCP', '예결/NNG', '위/NNG', '전체/NNG', '회의/NNG', '거치/VV', '이날/NNG', '오후/NNG', '시/NNB', '국회/NNG', '본회의/NNG', '추경안/NNG', '처리/NNG', '합의/NNG', '상태/NNG', '예결/NNG', '위/NNG', '전체/NNG', '회의/NNG', '불발/NNG', '경우/NNG', '본회의/NNG', '추경안/NNG', '처리/NNG', '어렵/VA', '지/VX', '수/NNB', '있/VX']
# 1600

# %%
model_ko = Word2Vec(seq, min_count=1, size=300) 
tokenizer = Tokenizer(num_words=30000)
tokenizer.fit_on_texts(trainTexts)  # train on `texts (list of sample texts)`
tokenizer.fit_on_texts(testTexts) 
trainSequences = tokenizer.texts_to_sequences(trainTexts)  # return list of sequences (one per text)
testSequences = tokenizer.texts_to_sequences(testTexts)

# %%
print(sequences[0])
# Out:
# [4713, 975, 10805, 773, 1210, 1211, 1091, 2619, 596, 1092, 773, 8941, 606, 1430, 429, 6152, 1210, 138, 5084, 939, 879, 35, 180, 157, 1761, 1762, 908, 30, 219, 10806, 745, 975, 10805, 35, 1999, 773, 5, 71, 1210, 14105, 1231, 132, 812, 1092, 773, 48, 167, 2330, 845, 6868, 802, 181, 1210, 14106, 1211, 1092, 773, 456, 6153, 423, 1922, 429, 1706, 4, 9, 35, 1407, 78, 1231, 2169, 180, 157, 5, 378, 82, 4713, 745, 2000, 1, 1092, 773, 157, 271, 6, 24, 125, 350, 10807, 1, 1091, 606, 340, 2, 1092, 773, 26, 21, 5569, 14107, 14108, 1, 1091, 606, 2001, 225, 160, 21, 85, 5569, 99, 1270, 3256, 3630, 6, 341, 288, 2, 74, 6869, 187, 180, 77, 1659, 225, 1248, 41, 408, 5569, 291, 1338, 107, 774, 35, 1707, 7734, 14109, 2520, 955, 2961, 2962, 2521, 41, 1092, 773, 2520, 2962, 7735, 457, 67, 341, 4, 1210, 2243, 1092, 773, 38, 131, 745, 975, 33, 46, 1091, 57, 44, 3, 33, 1, 1091, 57, 157, 50, 278, 582, 271, 6, 24, 3, 1, 44, 12]

# %%
words = list(model_ko.wv.vocab)
print(words)
# Out:
V', '듯/NNB', '문무/NNG', '왼쪽/NNG', '김지헌/NNP', '검찰/NNG', '숱하/VA', '끝/NNG', '대하/VV', '구속영장/NNP', '청구/NNG', '권/NNB', '신병/NNG', '어떻/VA', '강원랜드/NNP', '채용/NNG', '비리/NNG', '단장/NNG', '양부/NNG', '광주지검/NNP', '장/NNB', '업무방해/NNP', '자/NNB', '뇌물수수/NNP', '직권/NNG', '남용/NNG', '권리/NNG', '행사/NNG', '방해/NNG', '혐의/NNG', '밝히/VV', '현직/NNG', '수사/NNG', '언론/NNG', '나오/VV', '춘천지검/NNP', '최흥집/NNP', '사장/NNG', '사건/NNG', '사법연수원/NNP', '기/NNB', '의정부지검/NNP', '최종원/NNP', '서울남부지검/NNP', '조기/NNG', '종결/NNG', '지시/NNG', '2월 4일/NNP', '주장/NNG', '진행/NNG', '중/NNB', '국회 법제사법위원회/NNP', '고검장/NNG', '측근/NNG', '사이/NNG', '연락/NNG', '오가/VV', '의심/NNG', '정황/NNG', '상관/NNG', '대상/NNG', '불편/NNG', '하/VX', '듣/VV', '염동열/NNP', '이름/NNG', '등장/NNG', '증거/NNG', '목록/NNG', '삭제/NNG', '달/VX', '압력/NNG', '지속/NNG', '받/VV', '수사단장/NNG', '자료/NNG', '사진/NNG', '국회의원/NNG', '유착/NNG', '장/NNG', '독립/NNG', '꾸리/VV', '승부수/NNG', '던지/VV', '의혹/NNG', '해소/NNG', '지침/NNG', '아래/NNG', '활동/NNG', '기한/NNG', '정하/VV', '대검찰청/NNP', '사항/NNG', '보고/NNG', '뒤/NNG', '점검/NNG', '보장/NNG', '흔들리/VV', '체면/NNG', '회복/NNG', '취지/NNG', '보/VV', '이후/NNG', '부메랑/NNG', '되/VV', '돌아오/VV', '알리/VV', '출범/NNG', '당시/NNG', '공언/NNG', '지휘/NNG', '전문/NNG', '자문단/NNG', '가칭/NNG', '문/NNG', '총장/NNG', '어기/VV', '공개/NNG', '이/NP', '일종/NNG', '받아들이/VV', '다음날/NNG', '바르/VA', '공정/NNG', '관리/NNG', '감독/NNG', '직무/NNG', '생각/NNG', '정면/NNG', '반박/NNG', '전화/NNG', '가하/VV', '김우현/NNP', '부패/NNG', '부장/NNG', '검사장/NNG', '급/NNG', '기소/NNG', '격랑/NNG', '휘말리/VV', '마라톤/NNG', '고위/NNG', '부분/NNG', '불기소/NNP', '맞/VV', '의견/NNG', '내/VV', '따르/VV', '일단락/NNG', '앞/NNG', '남/VV', '절차/NNG', '피의자/NNG', '심문/NNG', '실질/NNG', '임시/NNG', '회기/NNG', '체포/NNG', '동의/NNG', '지원자/NNG', '수십/NR', '명/NNB', '부당/NNG', '청탁/NNG', '달/NNG', '법원/NNG', '요구/NNG', '송부/NNG', '대검/NNG', '법무부/NNG', '이송/NNG', '국무총리/NNG', '결재/NNG', '대통령/NNG', '재가/NNG', '제출/NNG', '만큼/NNB', '홍영표/NNP', '빠/NNG', '찍히/VV', '특검/NNG', '문자/NNG', '폭탄/NNG', '공격/NNG', '대표/NNG', '문재인/NNP', '더불/VV', '민주/NNG', '신임/NNG', '원내대표/NNP', '최근/NNG', '극렬/NNG', '지지자/NNG', ...
