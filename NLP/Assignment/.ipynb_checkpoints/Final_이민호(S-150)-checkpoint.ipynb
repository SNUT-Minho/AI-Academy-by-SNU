# %%
# import library
import os
import sys
sys.path.append(os.pardir) 
import nltk, re
import numpy as np
import matplotlib.pyplot as plt

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Embedding, Dense, Input, Bidirectional, LSTM, Dropout
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint

import konlpy
from konlpy.tag import Komoran
from konlpy.tag import Twitter
from konlpy.tag import Hannanum
from gensim.models import Word2Vec

import pickle
import codecs
import csv
import struct
# Out:
# Using TensorFlow backend.
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
TEXT_DATA_DIR = './newsData'
directory_label = {0: '정치', 1: '경제', 2: '사회', 3 : '생활/문화', 4 : '세계', 5 : '기술/IT', 6 : '연예', 7 : '스포츠'}

# %%
#WORD_EMBEDDING_WORD2VEC = './wiki.ko/wiki.ko.bin'
#WORD_EMBEDDING_WORD2VEC = './wiki.ko/wiki.ko.vec'

# %%
# parameter
EMBEDDING_DIM = 100
#EMBEDDING_DIM = 200
#EMBEDDING_DIM = 300

# %%
TEST_SPLIT = 0.15
VALIDATION_SPLIT = 0.15

# %%
# konlp Objects
komo = Komoran()
twitter = Twitter()
hannanum = Hannanum()

# %%
# list of texts
Texts = []  
trainTexts = []
validationTexts = []
testTexts = []

# %%
# list of label ids
Labels = []
trainLabels = []  
validationLabels = []
testLabels = []

# %%
# dictionary mapping label name to numeric id
labels_index = {}

# %%
# sequence of texts
seq = []

# %%
print(Texts)
# Out:
# []

# %%
# load texts data
for name in sorted(os.listdir(TEXT_DATA_DIR)):
    path = os.path.join(TEXT_DATA_DIR, name)
    if os.path.isdir(path):
        label_id = len(labels_index)
        labels_index[directory_label[int(name)]] = label_id
        for fname in sorted(os.listdir(path)):
            fpath = os.path.join(path, fname)
            args = {'encoding': 'utf-8'}
            if(re.findall('.1[6789][0-9]NewsData',fpath)):
                # test texts
                text = []
                with open(fpath, **args) as f:
                    t = f.read()
                    #pos = twitter.pos(t.strip())
                    #pos = hannanum.pos(t.strip())
                    pos = komo.pos(t.strip())
                    for pair in pos :
                        #['NNG', 'NNP', 'VV', 'VA']: part-of-speech of content word
                        if (re.findall('^[NV]',pair[1])):
                            morpheme = pair[0]+'/'+pair[1]
                            text.append(morpheme)
                    testTexts.append(text)
                testLabels.append(label_id)
            else :
                # train & validation texts
                text = []
                with open(fpath, **args) as f:
                    t = f.read()
                    #pos = twitter.pos(t.strip())
                    #pos = hannanum.pos(t.strip())
                    pos = komo.pos(t.strip())
                    for pair in pos :
                        if (re.findall('^[NV]',pair[1])):
                            morpheme = pair[0]+'/'+pair[1]
                            text.append(morpheme)
                    Texts.append(text)
                Labels.append(label_id)
            seq.append(text)
print('Found %s texts.' % len(Texts))
print('Found %s texts.' % len(testTexts))
print(len(Labels))
print(len(testLabels))
# Out:
# Found 1280 texts.
# Found 320 texts.
# 1280
# 320

# %%
import seaborn as sns
sns.set(color_codes=True)

'''
print("mean : ", np.mean(trainLen))
print("max : " ,np.max(trainLen))
print("min : " ,np.min(trainLen))
'''
# Out:
# '\nprint("mean : ", np.mean(trainLen))\nprint("max : " ,np.max(trainLen))\nprint("min : " ,np.min(trainLen))\n'

# %%
#MAX_FEATURES = 10000
MAX_FEATURES = 20000
#MAX_FEATURES = 30000

# %%
#Word2Vec
model_ko = Word2Vec(seq, min_count=1, size=EMBEDDING_DIM) 
words = list(model_ko.wv.vocab)
embeddings_index = {}
for i in words:
    embeddings_index[i] = model_ko[i]
# Out:
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
print(len(Texts))
# Out:
# 1280

# %%
# by default, validation_split in `fit` does not shuffle the data
indices = np.arange(len(Texts), dtype=int)
print(type(indices[0]))
# Out:
# <class 'numpy.int32'>

# %%
indices = np.arange(len(Texts))
print(indices)
np.random.shuffle(indices)

Texts = np.array(Texts)
Labels = np.array(Labels)

Texts = Texts[indices]
Labels = Labels[indices]

indices2 = np.arange(len(testTexts))
np.random.shuffle(indices2)

testTexts = np.array(testTexts)
testLabels = np.array(testLabels)

testTexts = testTexts[indices2]
testLabels = testLabels[indices2]
# Out:
# [   0    1    2 ... 1277 1278 1279]

# %%
num_validation_samples = int(VALIDATION_SPLIT * len(Texts))

validationTexts = Texts[:num_validation_samples]
validationLabels = Labels[:num_validation_samples]

trainTexts = Texts[num_validation_samples:]
trainLabels = Labels[num_validation_samples:]

# %%
print(len(trainTexts))
print(len(validationTexts))
print(len(testTexts))
# Out:
# 1088
# 192
# 320

# %%
# train & validation texts의 길이 분포 list
trainLen  = list()
for i in range(len(trainTexts)):
    trainLen.append(len(trainTexts[i]))

# %%
# train & validation texts의 길이 분포 list
validationLen  = list()
for i in range(len(validationTexts)):
    validationLen.append(len(validationTexts[i]))

# %%
# test texts의 길이 분포 list
testLen  = list()
for i in range(len(testTexts)):
    testLen.append(len(testTexts[i]))

# %%
# 각 text별로 길이 분포
sns.distplot(trainLen, hist = True, rug =True);
sns.distplot(validationLen, hist = True, rug =True);
sns.distplot(testLen, hist= True, rug =True)
plt.show()
# Out:
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\MinhoLee\Anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
MAX_SEQUENCE_LENGTH = 150
#MAX_SEQUENCE_LENGTH = 200
#MAX_SEQUENCE_LENGTH = 250
#MAX_SEQUENCE_LENGTH = 300
#MAX_SEQUENCE_LENGTH = 350

# %%
# tokenizer 선언
tokenizer = Tokenizer(num_words=MAX_FEATURES)

TEXT = list()
for i in range(len(trainTexts)):
    TEXT.append(trainTexts[i])
    
for i in range(len(validationTexts)):
    TEXT.append(validationTexts[i]) 
    
for i in range(len(testTexts)):
    TEXT.append(testTexts[i])

# %%
# train on `texts token' (list of sample texts)`
# return list of sequences (one per text)

tokenizer.fit_on_texts(TEXT)
sequences = tokenizer.texts_to_sequences(TEXT)
sequences = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post')
print(len(sequences))
# sequence는 전체?
# Out:
# 1600

# %%
type(trainLabels)
# Out:
# numpy.ndarray

# %%
x_train = sequences[:1088]
y_train = to_categorical(trainLabels)

x_val = sequences[1088:1280]
y_val = to_categorical(validationLabels)

x_test = sequences[1280:]
y_test = to_categorical(testLabels)

# %%
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (1088, 8)
# (192, 8)
# (320, 8)

# %%
print(trainTexts[0])
print(x_train[0])
print(y_train[0])
# Out:
# ['안철수/NNP', '얘기/NNG', '말/VX', '이준석/NNP', '블랙/NNG', '하우스/NNG', '공격/NNG', '질문/NNG', '돌출/NNG', '발언/NNG', '이데일리/NNP', '박지혜/NNP', '기자/NNG', '지방선거/NNP', '서울/NNP', '노원/NNP', '병/NNG', '국회의원/NNG', '재·보궐 선거/NNP', '출마/NNG', '이준석/NNP', '바른/NNP', '미래/NNG', '후보/NNG', '같/VA', '당/NNG', '안철수/NNP', '서울시장/NNG', '후보/NNG', '관련/NNG', '질문/NNG', '신중/NNG', '모습/NNG', '보이/VV', '지나/VV', '일/NNB', '김어준/NNP', '블랙/NNG', '하우스/NNG', '개그우먼/NNG', '강유미/NNP', '노원/NNP', '병/NNG', '선거구/NNG', '출마/NNG', '당/NNG', '후보/NNG', '만나/VV', '가운데/NNG', '이준석/NNP', '후보/NNG', '강유미/NNP', '박근혜/NNP', '키즈/NNG', '이/VCP', '말/NNG', '어떻/VA', '생각/NNG', '이/VCP', '질문/NNG', '받/VV', '후보/NNG', '받아들이/VV', '사실/NNG', '누구/NP', '영입/NNG', '사람/NNG', '있/VX', '많/VA', '분/NNB', '모르/VV', '노무현/NNP', '대통령/NNG', '김영삼/NNP', '대통령/NNG', '키즈/NNG', '이/VCP', '분/NNB', '노/NNP', '대통령/NNG', '결정/NNG', '이/VCP', '시점/NNG', '본인/NNG', '정치/NNG', '하/VV', '때문/NNB', '크/VA', '정치인/NNG', '되/VV', '거/NNB', '저/NP', '그렇/VA', '되/VV', '답/NNG', '이/VCP', '공격/NNG', '질문/NNG', '이/VCP', '후보/NNG', '강유미/NNP', '하나/NR', '공격/NNG', '질문/NNG', '예고/NNG', '후보/NNG', '안철수/NNP', '얘기/NNG', '말/VX', '말/NNG', '장면/NNG', '스튜디오/NNG', '화면/NNG', '보/VV', '있/VV', '진행자/NNG', '김어준/NNP', '박장대소/NNG', '하/VV', '그렇/VA', '후보/NNG', '덜/VV', '저지/NNG', '질문/NNG', '이준석/NNP', '후보/NNG', '안철수/NNP', '잇/VV', '당시/NNG', '후보/NNG', '공천/NNG', '갈등/NNG', '주인공/NNG', '이/VCP', '후보/NNG', '국회의원/NNG', '시절/NNG', '지역구/NNG', '이/VCP', '노원/NNP', '병/NNG', '유승민/NNP', '후보/NNG', '공천/NNG', '신청/NNG', '당내/NNG', '계파/NNG', '갈등/NNG', '설/NNG', '불거지/VV', '후보/NNG', '가깝/VA', '김근식/NNP', '경남대/NNP', '교수/NNG', '노원/NNP', '병/NNG', '공천/NNG', '당내/NNG', '갈등/NNG', '고조/NNG', '출마/NNG', '포기/NNG', '바른/NNP', '미래/NNG', '지나/VV', '일/NNB', '노원/NNP', '병/NNG', '후보/NNG', '단수/NNG', '공천/NNG', '결정/NNG', '후보/NNG', '분/NNB', '후보/NNG', '우리/NP', '서울시장/NNG', '후보/NNG', '이/VCP', '나/NP', '강하/VA', '단련/NNG', '주/VX', '트레이너/NNG', '역할/NNG', '하/VV', '것/NNB', '같/VA', '강하/VA', '단련/NNG', '있/VV', '잠/NNG', '자/VV', '말/NNG', '공천/NNG', '갈등/NNG', '인하/VV', '밤잠/NNG', '설치/VV', '것/NNB', '사람/NNG', '인연/NNG', '년/NNB', '대/NNB', '총선/NNG', '거스르/VV', '올라가/VV', '당시/NNG', '후보/NNG', '박근혜/NNP', '키즈/NNG', '노원/NNP', '병/NNG', '국민의당/NNP', '후보/NNG', '이/VCP', '후보/NNG', '격돌/NNG', '후보/NNG', '새누리당/NNP', '탈당/NNG', '바른/NNP', '정당/NNG', '입당/NNG', '바른/NNP', '정당/NNG', '국민의당/NNP', '바른/NNP', '미래/NNG', '후보/NNG', '만나/VV']
# [  750  1306   415     4    44    39  3419    11   255   449   229    11
#    792     1   660   435     1    69 10415   391   660   435  1512    69
#   1577   596   535    12  1290  1027  1140    28     3  6029  3735 16159
#      4   229    69  3560  3281   435  5571    69  1577   661   127    69
#    839   871  1942     1    69  1026  1242  4106     1  3027  1025  2552
#     69   839   529  3736  7989   871  1579  1291    69  1106  7990  7205
#    200  3027  1025   839  3736   871  2378   821  1222   484   290    27
#      5  3027  1025    69  7991   839   196    69    54    69    76  3418
#     69     1   166   403  7992    30 10417   409     4     2    35   403
#   7992     3  2553  1758    12   839   871   316 10418 10419     2    49
#   2554     9    41  3157  5177  2243   127    69  2807  2907  3027  1025
#   3923    69     1    69  6030    69  5572  4840   484  1223  7993   484
#   1223  3923   484   290    69   187]
# [1. 0. 0. 0. 0. 0. 0. 0.]

# %%
# Map: word -> rank/index(int) in text
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
print(word_index)
# Out:
# Found 25196 unique tokens.
# {'이/VCP': 1, '것/NNB': 2, '있/VV': 3, '하/VV': 4, '일/NNB': 5, '있/VX': 6, '등/NNB': 7, '수/NNB': 8, '년/NNB': 9, '않/VX': 10, '되/VV': 11, '말/NNG': 12, '지/VX': 13, '대하/VV': 14, '원/NNB': 15, '없/VA': 16, '명/NNB': 17, '만/NR': 18, '이/NP': 19, '받/VV': 20, '기자/NNG': 21, '월/NNB': 22, '밝히/VV': 23, '씨/NNB': 24, '위하/VV': 25, '중/NNB': 26, '지나/VV': 27, '보/VV': 28, '따르/VV': 29, '주/VX': 30, '보이/VV': 31, '서울/NNP': 32, '아니/VCN': 33, '억/NR': 34, '같/VA': 35, '북한/NNP': 36, '시간/NNG': 37, '통하/VV': 38, '크/VA': 39, '때/NNG': 40, '대/NNB': 41, '이번/NNG': 42, '미국/NNP': 43, '때문/NNB': 44, '시/NNB': 45, '대통령/NNG': 46, '관련/NNG': 47, '그/NP': 48, '사람/NNG': 49, '이날/NNG': 50, '나오/VV': 51, '경찰/NNG': 52, '김/NNP': 53, '분/NNB': 54, '조사/NNG': 55, '이후/NNG': 56, '한국/NNP': 57, '하/VX': 58, '많/VA': 59, '번/NNB': 60, '중국/NNP': 61, '전하/VV': 62, '개/NNB': 63, '경우/NNG': 64, '대표/NNG': 65, '문제/NNG': 66, '지난해/NNG': 67, '사실/NNG': 68, '후보/NNG': 69, '관계자/NNG': 70, '정부/NNG': 71, '높/VA': 72, '의원/NNG': 73, '못하/VX': 74, '혐의/NNG': 75, '우리/NP': 76, '대회/NNG': 77, '상황/NNG': 78, '점/NNB': 79, '후/NNG': 80, '뒤/NNG': 81, '최근/NNG': 82, '진행/NNG': 83, '측/NNB': 84, '간/NNB': 85, '열리/VV': 86, '오/VV': 87, '좋/VA': 88, '알리/VV': 89, '시장/NNG': 90, '결과/NNG': 91, '위/NNB': 92, '이상/NNG': 93, '수사/NNG': 94, '자신/NNG': 95, '팀/NNG': 96, '지역/NNG': 97, '주장/NNG': 98, '예정/NNG': 99, '확인/NNG': 100, '가/VV': 101, '오/VX': 102, '만/NNB': 103, '들/VV': 104, '오르/VV': 105, '연구/NNG': 106, '시작/NNG': 107, '설명/NNG': 108, '전/NNG': 109, '내/NP': 110, '건/NNB': 111, '사건/NNG': 112, '알/VV': 113, '오후/NNG': 114, '가격/NNG': 115, '조/NR': 116, '만들/VV': 117, '안/NNG': 118, '공개/NNG': 119, '게/NNG': 120, '입장/NNG': 121, '생각/NNG': 122, '국내/NNG': 123, '정도/NNG': 124, '천/NR': 125, '회담/NNG': 126, '당시/NNG': 127, '모습/NNG': 128, '곳/NNG': 129, '문/NNG': 130, '데/NNB': 131, '연합뉴스/NNP': 132, '방송/NNG': 133, '필요/NNG': 134, '미/NNP': 135, '드/NNP': 136, '일/NNG': 137, '회장/NNG': 138, '사용/NNG': 139, '올해/NNG': 140, '세/NNB': 141, '발표/NNG': 142, '세계/NNG': 143, '트럼프/NNP': 144, '위원장/NNG': 145, '일본/NNP': 146, '이유/NNG': 147, '경기/NNG': 148, '발생/NNG': 149, '정상회담/NNP': 150, '먹/VV': 151, '여성/NNG': 152, '사고/NNG': 153, '계획/NNG': 154, '루킹/NNP': 155, '과정/NNG': 156, '일부/NNG': 157, '살/VV': 158, '배/NNG': 159, '검찰/NNG': 160, '앞/NNG': 161, '선수/NNG': 162, '내용/NNG': 163, '상태/NNG': 164, '처리/NNG': 165, '나/NP': 166, '이용/NNG': 167, '한국당/NNP': 168, '국회/NNG': 169, '기록/NNG': 170, '사업/NNG': 171, '오전/NNG': 172, '현지/NNG': 173, '달러/NNB': 174, '수준/NNG': 175, '예상/NNG': 176, '서비스/NNG': 177, '나서/VV': 178, '한편/NNG': 179, '쓰/VV': 180, '논란/NNG': 181, '차/NNB': 182, '정상/NNG': 183, '증가/NNG': 184, '기준/NNG': 185, '내리/VV': 186, '만나/VV': 187, '분석/NNG': 188, '달/NNG': 189, '지적/NNG': 190, '지원/NNG': 191, '규모/NNG': 192, '어렵/VA': 193, '도/NNB': 194, '보도/NNG': 195, '결정/NNG': 196, '북/NNP': 197, '합의/NNG': 198, '북미/NNP': 199, '교수/NNG': 200, '대상/NNG': 201, '지난달/NNG': 202, '집/NNG': 203, '내/VV': 204, '기술/NNG': 205, '요구/NNG': 206, '댓글/NNP': 207, '가운데/NNG': 208, '전망/NNG': 209, '위/NNG': 210, '보/VX': 211, '활동/NNG': 212, '아이/NNG': 213, '만큼/NNB': 214, '출시/NNG': 215, '처음/NNG': 216, '맞/VV': 217, '사진/NNG': 218, '넘/VV': 219, '상승/NNG': 220, '나타나/VV': 221, '올리/VV': 222, '평가/NNG': 223, '특검/NNG': 224, '강조/NNG': 225, '관계/NNG': 226, '직원/NNG': 227, '국제/NNG': 228, '그렇/VA': 229, '게임/NNG': 230, '차량/NNG': 231, '업계/NNG': 232, '개월/NNB': 233, '업체/NNG': 234, '이어지/VV': 235, '피해/NNG': 236, '회/NNB': 237, '최고/NNG': 238, '기업/NNG': 239, '놓/VX': 240, '영향/NNG': 241, '해당/NNG': 242, '발견/NNG': 243, '열/VV': 244, '우려/NNG': 245, '바/NNB': 246, '평화/NNG': 247, '제품/NNG': 248, '경제/NNG': 249, '종합/NNG': 250, '포함/NNG': 251, '국민/NNG': 252, '원내대표/NNP': 253, '판매/NNG': 254, '거/NNB': 255, '보내/VV': 256, '사이/NNG': 257, '찾/VV': 258, '싶/VX': 259, '내/VX': 260, '두/VV': 261, '협상/NNG': 262, '스마트폰/NNP': 263, '차/NNG': 264, '추가/NNG': 265, '해외/NNG': 266, '회사/NNG': 267, '떨어지/VV': 268, '당국/NNG': 269, '속/NNG': 270, '남북/NNP': 271, '민주당/NNP': 272, '최대/NNG': 273, '남성/NNG': 274, '오늘/NNG': 275, '우승/NNG': 276, '단체/NNG': 277, '덧붙이/VV': 278, '준비/NNG': 279, '개최/NNG': 280, '상대/NNG': 281, '운영/NNG': 282, '새롭/VA': 283, '가 ...

# %%
num_words = min(MAX_FEATURES, len(word_index) + 1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_FEATURES:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all zeros.
        embedding_matrix[i] = embedding_vector

# %%
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix], 
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# %%
# path where all models are saved
BASE_PATH = './newsModel/'
if not os.path.exists(BASE_PATH):
    os.mkdir(BASE_PATH)

# %%
def create_checkpoint(model_name):
    # creates a subdirectory under `BASE_PATH`
    MODEL_PATH = os.path.join(BASE_PATH, model_name)
    if not os.path.exists(MODEL_PATH):
        os.mkdir(MODEL_PATH)
    
    return ModelCheckpoint(filepath=os.path.join(MODEL_PATH, '{epoch:02d}-{val_loss:.4f}.hdf5'),
                           monitor='val_loss',
                           verbose=1,
                           save_best_only=True)

# %%
batch_size = 128
max_epochs = 30
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=3)

# %%
print('Training...')

# train a 3-layer bi-LSTM model
sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)

x = Bidirectional(LSTM(128, return_sequences=True))(embedded_sequences)
x = Dropout(0.5)(x)
x = Bidirectional(LSTM(128, return_sequences=True))(x)
x = Dropout(0.5)(x)
x = Bidirectional(LSTM(128))(x)
x = Dropout(0.5)(x)
preds = Dense(len(labels_index), activation='softmax')(x)

model = Model(sequence_input, preds)

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

checkpoint = create_checkpoint('lstm')  # checkpoint callback
history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=max_epochs,
          validation_data=(x_val, y_val),
          shuffle=True,
          callbacks= [checkpoint])
# Out:
# Training...
# Train on 1088 samples, validate on 192 samples
# Epoch 1/100
#  256/1088 [======>.......................] - ETA: 44s - loss: 2.0890 - acc: 0.1484
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-016102482e5d> in <module>()
#      25           validation_data=(x_val, y_val),
#      26           shuffle=True,
# ---> 27           callbacks= [checkpoint])
#
# ~\Anaconda3\envs\venv\lib\site-packages\keras-2.2.0-py3.6.egg\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1040                                         initial_epoch=initial_epoch,
#    1041                                         steps_per_epoch=steps_per_epoch,
# -> 1042                                         validation_steps=validation_steps)
#    1043
#    1044     def evaluate(self, x=None, y=None,
#
# ~\Anaconda3\envs\venv\lib\site-packages\keras-2.2.0-py3.6.egg\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 if not isinstance(outs, list):
#     201                     outs = [outs]
#
# ~\Anaconda3\envs\venv\lib\site-packages\keras-2.2.0-py3.6.egg\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2659                 return self._legacy_call(inputs)
#    2660
# -> 2661             return self._call(inputs)
#    2662         else:
#    2663             if py_any(is_tensor(x) for x in inputs):
#
# ~\Anaconda3\envs\venv\lib\site-packages\keras-2.2.0-py3.6.egg\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2629                                 symbol_vals,
#    2630                                 session)
# -> 2631         fetched = self._callable_fn(*array_vals)
#    2632         return fetched[:len(self.outputs)]
#    2633
#
# ~\Anaconda3\envs\venv\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:

# %%
# Visualize training (optional)
# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots(figsize=(8,8))
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_ylim([0.0, 3.0])

acc_ax.plot(history.history['acc'], 'b', label='train acc')
acc_ax.plot(history.history['val_acc'], 'g', label='val acc')
acc_ax.set_ylim([0.0, 1.0])

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
loss, acc = model.evaluate(x_test, y_test,
                           batch_size=batch_size)

print(f'----- Evaluation loss and metrics for {len(y_test)} test samples -----')
print('Test loss:', loss)
print('Test accuracy:', acc)
# Out:
# 320/320 [==============================] - 4s 13ms/step
# ----- Evaluation loss and metrics for 320 test samples -----
# Test loss: 1.8770819187164307
# Test accuracy: 0.3
