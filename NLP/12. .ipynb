# %% [markdown]
# ![%EC%BA%A1%EC%B2%98.PNG](attachment:%EC%BA%A1%EC%B2%98.PNG)

# %%
- 여기에 punctuation 부분에 지우고싶은 단어들 (regular expression와 같은거 넣으면됨)
- 케라스에서 제공하는 Layer를 사용하고싶으면 저기 싸이트에서 데이터 가공하는법을 거쳐야된다? (외부 Embedding 하려면?)

# %%
- 160
